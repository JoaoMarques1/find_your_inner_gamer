# %%
import pandas as pd

# %%
df = pd.read_csv('../raw_data/steam_games.csv')

# %%
df.head()
# Out:
#                                                  url types  \
# 0    https://store.steampowered.com/app/379720/DOOM/   app
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
# 3    https://store.steampowered.com/app/221100/DayZ/   app
# 4  https://store.steampowered.com/app/8500/EVE_On...   app
#
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         desc_snippet  \
# 0  Now includes all three premium DLC packs (Unto...
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
# 3  The post-soviet country of Chernarus is struck...
# 4  EVE Online is a community-driven spaceship MMO...
#
#                                       recent_reviews  \
# 0  Very Positive,(554),- 89% of the 554 user revi...
# 1  Mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2  Mixed,(166),- 54% of the 166 user reviews in t...
# 3  Mixed,(932),- 57% of the 932 user reviews in t...
# 4  Mixed,(287),- 54% of the 287 user reviews in t...
#
#                                          all_reviews  release_date  \
# 0  Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
# 3  Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4  Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
#
#              developer                                publisher  \
# 0          id Software    Bethesda Softworks,Bethesda Softworks
# 1     PUBG Corporation        PUBG Corporation,PUBG Corporation
# 2  Harebrained Schemes  Paradox Interactive,Paradox Interactive
# 3  Bohemia Interactive  Bohemia Interactive,Bohemia Interactive
# 4                  CCP                                  CCP,CCP
#
#                                         popular_tags  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                         game_details  \
# 0  Single-player,Multi-player,Co-op,Steam Achieve...
# 1             Multi-player,Online Multi-Player,Stats
# 2  Single-player,Multi-player,Online Multi-Player...
# 3  Multi-player,Online Multi-Player,Steam Worksho...
# 4  Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                            languages  achievements  \
# 0  English,French,Italian,German,Spanish - Spain,...          54.0
# 1  English,Korean,Simplified Chinese,French,Germa...          37.0
# 2                      English,French,German,Russian         128.0
# 3  English,French,Italian,German,Spanish - Spain,...           NaN
# 4                      English,German,Russian,French           NaN
#
#                                                genre  \
# 0                                             Action
# 1             Action,Adventure,Massively Multiplayer
# 2                          Action,Adventure,Strategy
# 3             Action,Adventure,Massively Multiplayer
# 4  Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                     game_description  \
# 0   About This Game Developed by id software, the...
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2   About This Game  From original BATTLETECH/Mec...
# 3   About This Game The post-soviet country of Ch...
# 4                                  About This Game
#
#                                       mature_content  \
# 0                                                NaN
# 1   Mature Content Description  The developers de...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 minimum_requirements  \
# 0  Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 1  Minimum:,Requires a 64-bit processor and opera...
# 2  Minimum:,Requires a 64-bit processor and opera...
# 3  Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4  Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
#
#                             recommended_requirements original_price  \
# 0  Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...         $19.99
# 1  Recommended:,Requires a 64-bit processor and o...         $29.99
# 2  Recommended:,Requires a 64-bit processor and o...         $39.99
# 3  Recommended:,OS:,Windows 10 64-bit,Processor:,...         $44.99
# 4  Recommended:,OS:,Windows 10,Processor:,Intel i...           Free
#
#   discount_price
# 0         $14.99
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40833 entries, 0 to 40832
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   url                       40833 non-null  object
#  1   types                     40831 non-null  object
#  2   name                      40817 non-null  object
#  3   desc_snippet              27612 non-null  object
#  4   recent_reviews            2706 non-null   object
#  5   all_reviews               28470 non-null  object
#  6   release_date              37654 non-null  object
#  7   developer                 40490 non-null  object
#  8   publisher                 35733 non-null  object
#  9   popular_tags              37888 non-null  object
#  10  game_details              40313 non-null  object
#  11  languages                 40797 non-null  object
#  12  achievements              12194 non-null  float64
#  13  genre                     40395 non-null  object
#  14  game_description          37920 non-null  object
#  15  mature_content            2897 non-null   object
#  16  minimum_requirements      21069 non-null  object
#  17  recommended_requirements  21075 non-null  object
#  18  original_price            35522 non-null  object
#  19  discount_price            14543 non-null  object
# dtypes: float64(1), object(19)
# memory usage: 6.2+ MB

# %%
df.types.value_counts()
# Out:
# app       38021
# bundle     2572
# sub         238
# Name: types, dtype: int64

# %% [markdown]
# # Publisher

# %%
### Publisher cleaning sub
def clean_pub(x):
    if ',' in str(x):
        if x.split(',')[0] == x.split(',')[1]:
            return x.split(',')[0]

# %%
df['publisher'] = df['publisher'].apply(lambda x : clean_pub(x))

# %%
### null values for pub
df[(df.publisher.isnull() ==True)].count()
# Out:
# url                         10635
# types                       10633
# name                        10620
# desc_snippet                 4735
# recent_reviews                338
# all_reviews                  4535
# release_date                 7729
# developer                   10350
# publisher                       0
# popular_tags                 7755
# game_details                10393
# languages                   10599
# achievements                  887
# genre                       10297
# game_description             7762
# mature_content                436
# minimum_requirements         5447
# recommended_requirements     5448
# original_price               7947
# discount_price               5013
# dtype: int64

# %%
df[(df.publisher.isnull() == True)]
# Out:
#                                                      url   types  \
# 5      https://store.steampowered.com/bundle/5699/Gra...  bundle
# 6      https://store.steampowered.com/app/601150/Devi...     app
# 11     https://store.steampowered.com/app/567640/Dang...     app
# 15     https://store.steampowered.com/bundle/5641/Hea...  bundle
# 21     https://store.steampowered.com/app/787480/Phoe...     app
# ...                                                  ...     ...
# 40827  https://store.steampowered.com/app/899835/Rock...     app
# 40828  https://store.steampowered.com/app/899836/Rock...     app
# 40829  https://store.steampowered.com/app/899832/Rock...     app
# 40830  https://store.steampowered.com/app/906840/Fant...     app
# 40831  https://store.steampowered.com/app/906635/Mega...     app
#
#                                                     name  \
# 5             Grand Theft Auto V: Premium Online Edition
# 6                                        Devil May Cry 5
# 11                       Danganronpa V3: Killing Harmony
# 15                  Hearts of Iron IV: Mobilization Pack
# 21     Phoenix Wright: Ace Attorney Trilogy / 逆転裁判123...
# ...                                                  ...
# 40827  Rocksmith® 2014 Edition – Remastered – Sabaton...
# 40828  Rocksmith® 2014 Edition – Remastered – Sabaton...
# 40829  Rocksmith® 2014 Edition – Remastered – Stone T...
# 40830  Fantasy Grounds - Quests of Doom 4: A Midnight...
# 40831                       Mega Man X5 Sound Collection
#
#                                             desc_snippet  \
# 5      Grand Theft Auto V: Premium Online Edition bundle
# 6      The ultimate Devil Hunter is back in style, in...
# 11     A new cast of 16 characters find themselves ki...
# 15           Hearts of Iron IV: Mobilization Pack bundle
# 21     Become Phoenix Wright and experience the thril...
# ...                                                  ...
# 40827                                                NaN
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
#
#                                           recent_reviews  \
# 5                                                    NaN
# 6      Very Positive,(408),- 87% of the 408 user revi...
# 11     Very Positive,(78),- 82% of the 78 user review...
# 15                                                   NaN
# 21     Very Positive,(47),- 95% of the 47 user review...
# ...                                                  ...
# 40827                                                NaN
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
#
#                                              all_reviews  release_date  \
# 5                                                    NaN           NaN
# 6      Very Positive,(9,645),- 92% of the 9,645 user ...   Mar 7, 2019
# 11     Very Positive,(3,547),- 84% of the 3,547 user ...  Sep 25, 2017
# 15                                                   NaN           NaN
# 21     Very Positive,(382),- 97% of the 382 user revi...   Apr 9, 2019
# ...                                                  ...           ...
# 40827                                                NaN  Feb 12, 2019
# 40828                                                NaN  Feb 12, 2019
# 40829                                                NaN   Feb 5, 2019
# 40830                                                NaN  Jul 31, 2018
# 40831                                                NaN  Jul 24, 2018
#
#                         developer publisher  \
# 5                  Rockstar North      None
# 6                CAPCOM Co., Ltd.      None
# 11       Spike Chunsoft Co., Ltd.      None
# 15     Paradox Development Studio      None
# 21               CAPCOM Co., Ltd.      None
# ...                           ...       ...
# 40827     Ubisoft - San Francisco      None
# 40828     Ubisoft - San Francisco      None
# 40829     Ubisoft - San Francisco      None
# 40830         SmiteWorks USA, LLC      None
# 40831             CAPCOM CO., LTD      None
#
#                                             popular_tags  \
# 5                                                    NaN
# 6      Action,Hack and Slash,Great Soundtrack,Demons,...
# 11     Story Rich,Anime,Visual Novel,Detective,Myster...
# 15                                                   NaN
# 21     Visual Novel,Story Rich,Great Soundtrack,Detec...
# ...                                                  ...
# 40827                                  Casual,Simulation
# 40828                                  Casual,Simulation
# 40829                                  Casual,Simulation
# 40830  RPG,Indie,Strategy,Software,Turn-Based,Fantasy...
# 40831                                             Action
#
#                                             game_details  \
# 5      Single-player,Multi-player,Downloadable Conten...
# 6      Single-player,Online Multi-Player,Online Co-op...
# 11     Single-player,Steam Achievements,Full controll...
# 15     Single-player,Multi-player,Online Multi-Player...
# 21     Single-player,Steam Achievements,Steam Trading...
# ...                                                  ...
# 40827  Single-player,Shared/Split Screen,Downloadable...
# 40828  Single-player,Shared/Split Screen,Downloadable...
# 40829  Single-player,Shared/Split Screen,Downloadable...
# 40830  Multi-player,Co-op,Cross-Platform Multiplayer,...
# 40831  Single-player,Downloadable Content,Steam Achie...
#
#                                                languages  achievements  \
# 5      English, French, Italian, German, Spanish - Sp...           NaN
# 6      English,French,Italian,German,Spanish - Spain,...          51.0
# 11     English,French,Japanese,Simplified Chinese,Tra...          41.0
# 15     English, French, German, Polish, Portuguese - ...           NaN
# 21                                      English,Japanese          30.0
# ...                                                  ...           ...
# 40827  English,German,French,Italian,Spanish - Spain,...           NaN
# 40828  English,German,French,Italian,Spanish - Spain,...           NaN
# 40829  English,German,French,Italian,Spanish - Spain,...           NaN
# 40830                                            English           NaN
# 40831  English,French,Italian,German,Spanish - Spain,...           NaN
#
#                      genre                                   game_description  \
# 5         Action,Adventure                                                NaN
# 6                   Action   About This Game The Devil you know returns in...
# 11               Adventure   About This Game Welcome to a new world of Dan...
# 15     Simulation,Strategy                                                NaN
# 21               Adventure   About This Game The classic courtroom adventu...
# ...                    ...                                                ...
# 40827    Casual,Simulation   About This Content Play "Primo Victoria" by S...
# 40828    Casual,Simulation   About This Content Play "Ghost Division" by S...
# 40829    Casual,Simulation   About This Content Play "Trippin’ on a Hole i...
# 40830   Indie,RPG,Strategy   About This Content  Quests of Doom 4: A Midni...
# 40831               Action   About This Content Get equipped with the stun...
#
#                                           mature_content  \
# 5                                                    NaN
# 6       Mature Content Description  The developers de...
# 11                                                   NaN
# 15                                                   NaN
# 21                                                   NaN
# ...                                                  ...
# 40827                                                NaN
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
#
#                                     minimum_requirements  \
# 5                                                    NaN
# 6      Minimum:,OS:,WINDOWS® 7, 8.1, 10 (64-BIT Requi...
# 11     Minimum:,Requires a 64-bit processor and opera...
# 15                                                   NaN
# 21     Minimum:,OS:,WINDOWS® 7, 8.1, 10 (64bit),Proce...
# ...                                                  ...
# 40827  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40828  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40829  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40830  Minimum:,OS:,Windows 7x , 8x or 10x,Processor:...
# 40831  Minimum:,OS:,WINDOWS® 7 (64bit),Processor:,Int...
#
#                                 recommended_requirements original_price  \
# 5                                                    NaN            NaN
# 6      Recommended:,OS:,WINDOWS® 7, 8.1, 10 (64-BIT R...         $59.99
# 11     Recommended:,Requires a 64-bit processor and o...         $39.99
# 15                                                   NaN            NaN
# 21     Recommended:,OS:,WINDOWS® 7, 8.1, 10 (64bit),P...         $29.99
# ...                                                  ...            ...
# 40827  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40828  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40829  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40830  Recommended:,OS:,Windows 7x , 8x or 10x,Proces...          $7.99
# 40831  Recommended:,OS:,WINDOWS®10 (64bit),Processor:...          $9.99
#
#       discount_price
# 5             $35.18
# 6             $70.42
# 11            $59.97
# 15            $94.45
# 21            $38.25
# ...              ...
# 40827            NaN
# 40828            NaN
# 40829            NaN
# 40830            NaN
# 40831            NaN
#
# [10635 rows x 20 columns]

# %% [markdown]
# The below code is to run after the data scrapping!

# %%
#### Replacing missing publisher by developer - add inplace = True
#df.publisher = df.publisher.fillna(df.developer)

# %%
df[(df.publisher.isnull() == True)]
# Out:
#                                                      url   types  \
# 5      https://store.steampowered.com/bundle/5699/Gra...  bundle
# 6      https://store.steampowered.com/app/601150/Devi...     app
# 11     https://store.steampowered.com/app/567640/Dang...     app
# 15     https://store.steampowered.com/bundle/5641/Hea...  bundle
# 21     https://store.steampowered.com/app/787480/Phoe...     app
# ...                                                  ...     ...
# 40827  https://store.steampowered.com/app/899835/Rock...     app
# 40828  https://store.steampowered.com/app/899836/Rock...     app
# 40829  https://store.steampowered.com/app/899832/Rock...     app
# 40830  https://store.steampowered.com/app/906840/Fant...     app
# 40831  https://store.steampowered.com/app/906635/Mega...     app
#
#                                                     name  \
# 5             Grand Theft Auto V: Premium Online Edition
# 6                                        Devil May Cry 5
# 11                       Danganronpa V3: Killing Harmony
# 15                  Hearts of Iron IV: Mobilization Pack
# 21     Phoenix Wright: Ace Attorney Trilogy / 逆転裁判123...
# ...                                                  ...
# 40827  Rocksmith® 2014 Edition – Remastered – Sabaton...
# 40828  Rocksmith® 2014 Edition – Remastered – Sabaton...
# 40829  Rocksmith® 2014 Edition – Remastered – Stone T...
# 40830  Fantasy Grounds - Quests of Doom 4: A Midnight...
# 40831                       Mega Man X5 Sound Collection
#
#                                             desc_snippet  \
# 5      Grand Theft Auto V: Premium Online Edition bundle
# 6      The ultimate Devil Hunter is back in style, in...
# 11     A new cast of 16 characters find themselves ki...
# 15           Hearts of Iron IV: Mobilization Pack bundle
# 21     Become Phoenix Wright and experience the thril...
# ...                                                  ...
# 40827                                                NaN
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
#
#                                           recent_reviews  \
# 5                                                    NaN
# 6      Very Positive,(408),- 87% of the 408 user revi...
# 11     Very Positive,(78),- 82% of the 78 user review...
# 15                                                   NaN
# 21     Very Positive,(47),- 95% of the 47 user review...
# ...                                                  ...
# 40827                                                NaN
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
#
#                                              all_reviews  release_date  \
# 5                                                    NaN           NaN
# 6      Very Positive,(9,645),- 92% of the 9,645 user ...   Mar 7, 2019
# 11     Very Positive,(3,547),- 84% of the 3,547 user ...  Sep 25, 2017
# 15                                                   NaN           NaN
# 21     Very Positive,(382),- 97% of the 382 user revi...   Apr 9, 2019
# ...                                                  ...           ...
# 40827                                                NaN  Feb 12, 2019
# 40828                                                NaN  Feb 12, 2019
# 40829                                                NaN   Feb 5, 2019
# 40830                                                NaN  Jul 31, 2018
# 40831                                                NaN  Jul 24, 2018
#
#                         developer publisher  \
# 5                  Rockstar North      None
# 6                CAPCOM Co., Ltd.      None
# 11       Spike Chunsoft Co., Ltd.      None
# 15     Paradox Development Studio      None
# 21               CAPCOM Co., Ltd.      None
# ...                           ...       ...
# 40827     Ubisoft - San Francisco      None
# 40828     Ubisoft - San Francisco      None
# 40829     Ubisoft - San Francisco      None
# 40830         SmiteWorks USA, LLC      None
# 40831             CAPCOM CO., LTD      None
#
#                                             popular_tags  \
# 5                                                    NaN
# 6      Action,Hack and Slash,Great Soundtrack,Demons,...
# 11     Story Rich,Anime,Visual Novel,Detective,Myster...
# 15                                                   NaN
# 21     Visual Novel,Story Rich,Great Soundtrack,Detec...
# ...                                                  ...
# 40827                                  Casual,Simulation
# 40828                                  Casual,Simulation
# 40829                                  Casual,Simulation
# 40830  RPG,Indie,Strategy,Software,Turn-Based,Fantasy...
# 40831                                             Action
#
#                                             game_details  \
# 5      Single-player,Multi-player,Downloadable Conten...
# 6      Single-player,Online Multi-Player,Online Co-op...
# 11     Single-player,Steam Achievements,Full controll...
# 15     Single-player,Multi-player,Online Multi-Player...
# 21     Single-player,Steam Achievements,Steam Trading...
# ...                                                  ...
# 40827  Single-player,Shared/Split Screen,Downloadable...
# 40828  Single-player,Shared/Split Screen,Downloadable...
# 40829  Single-player,Shared/Split Screen,Downloadable...
# 40830  Multi-player,Co-op,Cross-Platform Multiplayer,...
# 40831  Single-player,Downloadable Content,Steam Achie...
#
#                                                languages  achievements  \
# 5      English, French, Italian, German, Spanish - Sp...           NaN
# 6      English,French,Italian,German,Spanish - Spain,...          51.0
# 11     English,French,Japanese,Simplified Chinese,Tra...          41.0
# 15     English, French, German, Polish, Portuguese - ...           NaN
# 21                                      English,Japanese          30.0
# ...                                                  ...           ...
# 40827  English,German,French,Italian,Spanish - Spain,...           NaN
# 40828  English,German,French,Italian,Spanish - Spain,...           NaN
# 40829  English,German,French,Italian,Spanish - Spain,...           NaN
# 40830                                            English           NaN
# 40831  English,French,Italian,German,Spanish - Spain,...           NaN
#
#                      genre                                   game_description  \
# 5         Action,Adventure                                                NaN
# 6                   Action   About This Game The Devil you know returns in...
# 11               Adventure   About This Game Welcome to a new world of Dan...
# 15     Simulation,Strategy                                                NaN
# 21               Adventure   About This Game The classic courtroom adventu...
# ...                    ...                                                ...
# 40827    Casual,Simulation   About This Content Play "Primo Victoria" by S...
# 40828    Casual,Simulation   About This Content Play "Ghost Division" by S...
# 40829    Casual,Simulation   About This Content Play "Trippin’ on a Hole i...
# 40830   Indie,RPG,Strategy   About This Content  Quests of Doom 4: A Midni...
# 40831               Action   About This Content Get equipped with the stun...
#
#                                           mature_content  \
# 5                                                    NaN
# 6       Mature Content Description  The developers de...
# 11                                                   NaN
# 15                                                   NaN
# 21                                                   NaN
# ...                                                  ...
# 40827                                                NaN
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
#
#                                     minimum_requirements  \
# 5                                                    NaN
# 6      Minimum:,OS:,WINDOWS® 7, 8.1, 10 (64-BIT Requi...
# 11     Minimum:,Requires a 64-bit processor and opera...
# 15                                                   NaN
# 21     Minimum:,OS:,WINDOWS® 7, 8.1, 10 (64bit),Proce...
# ...                                                  ...
# 40827  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40828  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40829  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40830  Minimum:,OS:,Windows 7x , 8x or 10x,Processor:...
# 40831  Minimum:,OS:,WINDOWS® 7 (64bit),Processor:,Int...
#
#                                 recommended_requirements original_price  \
# 5                                                    NaN            NaN
# 6      Recommended:,OS:,WINDOWS® 7, 8.1, 10 (64-BIT R...         $59.99
# 11     Recommended:,Requires a 64-bit processor and o...         $39.99
# 15                                                   NaN            NaN
# 21     Recommended:,OS:,WINDOWS® 7, 8.1, 10 (64bit),P...         $29.99
# ...                                                  ...            ...
# 40827  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40828  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40829  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40830  Recommended:,OS:,Windows 7x , 8x or 10x,Proces...          $7.99
# 40831  Recommended:,OS:,WINDOWS®10 (64bit),Processor:...          $9.99
#
#       discount_price
# 5             $35.18
# 6             $70.42
# 11            $59.97
# 15            $94.45
# 21            $38.25
# ...              ...
# 40827            NaN
# 40828            NaN
# 40829            NaN
# 40830            NaN
# 40831            NaN
#
# [10635 rows x 20 columns]

# %% [markdown]
# # Developer

# %%
### null values for pub
df[df.developer.isnull() ==True].count()
# Out:
# url                         343
# types                       341
# name                        327
# desc_snippet                200
# recent_reviews                4
# all_reviews                 161
# release_date                276
# developer                     0
# publisher                    58
# popular_tags                264
# game_details                257
# languages                   320
# achievements                 47
# genre                       197
# game_description            287
# mature_content               13
# minimum_requirements        179
# recommended_requirements    179
# original_price              250
# discount_price              114
# dtype: int64

# %% [raw]
# After manually checking the URLs it looks like we can complete the DB with webscrapping

# %% [markdown]
# # Popular Tags

# %%
#Hardware to delete fro DB
df[df['popular_tags'].str.contains("Hardware", na=False)]
# Out:
#                                                      url types  \
# 146    https://store.steampowered.com/app/353370/Stea...   app
# 2351   https://store.steampowered.com/app/384300/CPUC...   app
# 3609   https://store.steampowered.com/app/485900/Hard...   app
# 6599   https://store.steampowered.com/app/780100/Clea...   app
# 28942  https://store.steampowered.com/app/916980/Cryp...   app
# 33730  https://store.steampowered.com/app/530260/Stea...   app
# 40248  https://store.steampowered.com/app/358040/HTC_...   app
#
#                                      name  \
# 146                      Steam Controller
# 2351        CPUCores :: Maximize Your FPS
# 3609                   Hardware Engineers
# 6599         ClearMem :: Free Up Your RAM
# 28942                          CryptoFarm
# 33730  Steam Controller Wireless Receiver
# 40248                            HTC Vive
#
#                                             desc_snippet  \
# 146    Experience a new level of precise control for ...
# 2351   Maximize your FPS :: Use CPUCores to isolate a...
# 3609   Hardware Engineers is a simulation game where ...
# 6599   ClearMem is a cutting-edge application that do...
# 28942  Develop your own cryptocurrency farm and see h...
# 33730  Grab a wireless receiver (dongle) as a replace...
# 40248  VIVE is a first-of-its-kind virtual reality pl...
#
#                                           recent_reviews  \
# 146    Mostly Positive,(39),- 74% of the 39 user revi...
# 2351   Mixed,(59),- 62% of the 59 user reviews in the...
# 3609                                                 NaN
# 6599                                                 NaN
# 28942                                                NaN
# 33730                                                NaN
# 40248                                                NaN
#
#                                              all_reviews  release_date  \
# 146    Mostly Positive,(7,942),- 73% of the 7,942 use...  Nov 10, 2015
# 2351   Mostly Positive,(7,999),- 72% of the 7,999 use...   Jul 3, 2015
# 3609   Very Positive,(217),- 88% of the 217 user revi...  Apr 22, 2019
# 6599   Mixed,(45),- 48% of the 45 user reviews for th...  Jul 11, 2018
# 28942  Mostly Negative,(11),- 36% of the 11 user revi...  Sep 14, 2018
# 33730                                                NaN  Sep 29, 2016
# 40248                                                NaN   Apr 5, 2016
#
#                           developer        publisher  \
# 146                             NaN             None
# 2351   StartupTim, LLC,Tim Sullivan             None
# 3609                       Green127         Green127
# 6599   StartupTim, LLC,Tim Sullivan             None
# 28942               Wonderbox Games  Wonderbox Games
# 33730                           NaN             None
# 40248                           NaN             None
#
#                                             popular_tags  \
# 146    Controller,Hardware,Steam Machine,Local Multip...
# 2351   Utilities,Software,Singleplayer,Design & Illus...
# 3609   Simulation,Indie,Management,Singleplayer,Hardw...
# 6599   Utilities,Software,Indie,Action,Hardware,Mouse...
# 28942  Early Access,Simulation,Singleplayer,Minimalis...
# 33730                                           Hardware
# 40248  VR,Hardware,Futuristic,First-Person,Simulation...
#
#                                             game_details  \
# 146                                                  NaN
# 2351              Steam Achievements,Steam Trading Cards
# 3609   Single-player,Steam Achievements,Steam Worksho...
# 6599                                  Steam Achievements
# 28942  Single-player,Steam Achievements,Profile Featu...
# 33730                                                NaN
# 40248                                                NaN
#
#                                                languages  achievements  \
# 146                                                  NaN           NaN
# 2351   English,French,German,Polish,Russian,Simplifie...          15.0
# 3609   English,French,Italian,German,Spanish - Spain,...          32.0
# 6599   English,French,Italian,German,Spanish - Spain,...          13.0
# 28942  English,German,Simplified Chinese,Portuguese,R...          18.0
# 33730                                                NaN           NaN
# 40248                                                NaN           NaN
#
#                                  genre  \
# 146                              Valve
# 2351   Design & Illustration,Utilities
# 3609                  Indie,Simulation
# 6599                         Utilities
# 28942          Simulation,Early Access
# 33730                            Valve
# 40248                              HTC
#
#                                         game_description mature_content  \
# 146     About This Hardware Experience a new level of...            NaN
# 2351    About This Software  CPUCores is a cutting-ed...            NaN
# 3609    About This Game  Hardware Engineers is a simu...            NaN
# 6599    About This Software  ClearMem was created to ...            NaN
# 28942   About This Game  In this game you will become...            NaN
# 33730   About This Hardware Grab a wireless receiver ...            NaN
# 40248   About This Hardware  VIVE is a first-of-its-k...            NaN
#
#                                     minimum_requirements  \
# 146                                                  NaN
# 2351   Minimum:,OS:,Windows 7 64-bit, Windows 8 64-bi...
# 3609   Minimum:,OS:,Microsoft Windows 7/8.1/10,Proces...
# 6599   Minimum:,OS:,Windows 7 64-bit, Windows 8 64-bi...
# 28942                                                NaN
# 33730                                                NaN
# 40248                                                NaN
#
#                                 recommended_requirements original_price  \
# 146                                                  NaN         $49.99
# 2351   Recommended:,OS:,Windows 7 64-bit, Windows 8 6...         $14.99
# 3609   Recommended:,OS:,Microsoft Windows 10,Processo...         $14.99
# 6599   Recommended:,OS:,Windows 7 64-bit, Windows 8 6...          $9.99
# 28942                                                NaN          $7.99
# 33730                                                NaN         $12.99
# 40248                                                NaN        $499.00
#
#       discount_price
# 146              NaN
# 2351          $16.13
# 3609             NaN
# 6599             NaN
# 28942         $13.27
# 33730            NaN
# 40248            NaN

# %%
df[df.popular_tags.isnull() == True].count()
# Out:
# url                         2945
# types                       2943
# name                        2931
# desc_snippet                2837
# recent_reviews                 2
# all_reviews                   67
# release_date                 114
# developer                   2866
# publisher                     65
# popular_tags                   0
# game_details                2883
# languages                   2912
# achievements                   3
# genre                       2789
# game_description             118
# mature_content                 4
# minimum_requirements          41
# recommended_requirements      41
# original_price               617
# discount_price              2840
# dtype: int64

# %% [raw]
# Try to complete DB with web scrapping

# %%
### creating a loop of all the different tags, calculating the occurences to select the top used.
tags = {}
for index, row in df.iterrows():
    tags_list= str(row['popular_tags']).split(',')
    for tag in tags_list:
        if not tag in tags:
            tags[tag] = 1
        else:
            tags[tag] += 1

# %% [markdown]
# # Languages

# %%
### creating a loop of all the different languages, calculating the occurences to select the top used.
languages = {}
for index, row in df.iterrows():
    languages_list= str(row['languages']).split(',')
    for language in languages_list:
        if not language in languages:
            languages[language] = 1
        else:
            languages[language] += 1

languages_df = pd.DataFrame(list(languages.items()),columns = ['language','count'])
languages_df.sort_values('count', ascending =False)
# Out:
#                                              language  count
# 0                                             English  40718
# 3                                              German  13053
# 1                                              French  12515
# 4                                     Spanish - Spain  11555
# 8                                             Russian   9724
# ..                                                ...    ...
# 59               #lang_#lang_spanish*#lang_full_audio      1
# 60                                          Slovakian      1
# 61                      (all with full audio support)      1
# 63                                      #lang_german;      1
# 64  #lang_#lang_#lang_english**#lang_full_audio*#l...      1
#
# [65 rows x 2 columns]

# %%
df[df.languages.isnull() == True].count()
# Out:
# url                         36
# types                       34
# name                        24
# desc_snippet                23
# recent_reviews               1
# all_reviews                  1
# release_date                 3
# developer                   13
# publisher                    0
# popular_tags                 3
# game_details                13
# languages                    0
# achievements                 0
# genre                       17
# game_description            13
# mature_content               0
# minimum_requirements         1
# recommended_requirements     1
# original_price              20
# discount_price              26
# dtype: int64

# %% [raw]
# The only null value with a review is a Hardware

# %%
df[df.languages.isnull() == True]
# Out:
#                                                      url   types  \
# 146    https://store.steampowered.com/app/353370/Stea...     app
# 610            https://store.steampowered.com/sub/17093/     sub
# 704                      https://store.steampowered.com/     NaN
# 3410           https://store.steampowered.com/sub/18370/     sub
# 4847   https://store.steampowered.com/bundle/6191/The...     app
# 6381   https://store.steampowered.com/bundle/7125/Fac...     app
# 6710           https://store.steampowered.com/sub/52349/     sub
# 7869   https://store.steampowered.com/bundle/10241/Da...     app
# 9015           https://store.steampowered.com/sub/44774/     sub
# 9016           https://store.steampowered.com/sub/31492/     sub
# 9371           https://store.steampowered.com/sub/30561/     sub
# 9372           https://store.steampowered.com/sub/12357/     sub
# 9375           https://store.steampowered.com/sub/44370/     sub
# 9615   https://store.steampowered.com/bundle/8069/Hap...     app
# 9616   https://store.steampowered.com/bundle/7988/Scr...     app
# 9956   https://store.steampowered.com/bundle/5057/Del...     app
# 12146  https://store.steampowered.com/bundle/10912/Th...     app
# 12611  https://store.steampowered.com/bundle/2585/For...  bundle
# 12793  https://store.steampowered.com/bundle/698/Digi...  bundle
# 12879  https://store.steampowered.com/bundle/2663/PSY...     app
# 19192  https://store.steampowered.com/bundle/636/Batt...  bundle
# 20193          https://store.steampowered.com/sub/58401/     sub
# 20457  https://store.steampowered.com/bundle/1141/Bat...  bundle
# 20926          https://store.steampowered.com/sub/33925/     sub
# 21253          https://store.steampowered.com/sub/44369/     sub
# 21303          https://store.steampowered.com/sub/75825/     sub
# 23099  https://store.steampowered.com/bundle/5704/Hap...     app
# 25899          https://store.steampowered.com/sub/14857/     sub
# 28380  https://store.steampowered.com/bundle/10417/Ha...     app
# 33730  https://store.steampowered.com/app/530260/Stea...     app
# 34365  https://store.steampowered.com/bundle/5634/Dra...  bundle
# 35169   https://store.steampowered.com/digitalgiftcards/     NaN
# 39934  https://store.steampowered.com/app/1059530/Val...     app
# 40235         https://store.steampowered.com/sub/354233/     sub
# 40238         https://store.steampowered.com/sub/354231/     sub
# 40248  https://store.steampowered.com/app/358040/HTC_...     app
#
#                                                     name  \
# 146                                     Steam Controller
# 610             Total War: NAPOLEON - Definitive Edition
# 704                                                  NaN
# 3410                                  SimBin Mega Bundle
# 4847                                                 NaN
# 6381                                                 NaN
# 6710               Killing Floor - Character Pack Bundle
# 7869                                                 NaN
# 9015                                 BIT.TRIP Collection
# 9016                      Bit.Trip.Runner Franchise Pack
# 9371   Warhammer 40,000: Dawn of War II - Grand Maste...
# 9372                                  FEAR Complete Pack
# 9375                          Dawn of War Franchise Pack
# 9615                                                 NaN
# 9616                                                 NaN
# 9956                                                 NaN
# 12146                                                NaN
# 12611               Forge of Gods: Ultimate Titan Bundle
# 12793  Digital Sound Factory: Session Drummer 3 Expan...
# 12879                                                NaN
# 19192      Battle vs Chess - Grandmaster Premium Edition
# 20193  Crazy Machines: Wacky Contraption Ultimate Col...
# 20457              Battle vs Chess - Grandmaster Edition
# 20926                   99 Spirits - Complete Collection
# 21253  Warhammer 40,000: Dawn of War II - Retribution...
# 21303  The Incredible Adventures of Van Helsing Antho...
# 23099                                                NaN
# 25899                       Krater - Collector's Edition
# 28380                                                NaN
# 33730                 Steam Controller Wireless Receiver
# 34365           Dragon's Prophet Yeniyıl Özel Paketi - 2
# 35169                                                NaN
# 39934                                Valve Index Headset
# 40235                  Valve Index Headset + Controllers
# 40238                                 Valve Index VR Kit
# 40248                                           HTC Vive
#
#                                             desc_snippet  \
# 146    Experience a new level of precise control for ...
# 610      Total War: NAPOLEON - Definitive Edition bundle
# 704                                                  NaN
# 3410                           SimBin Mega Bundle bundle
# 4847                                                 NaN
# 6381                                                 NaN
# 6710        Killing Floor - Character Pack Bundle bundle
# 7869                                                 NaN
# 9015                          BIT.TRIP Collection bundle
# 9016               Bit.Trip.Runner Franchise Pack bundle
# 9371   Warhammer 40,000: Dawn of War II - Grand Maste...
# 9372                           FEAR Complete Pack bundle
# 9375                   Dawn of War Franchise Pack bundle
# 9615                                                 NaN
# 9616                                                 NaN
# 9956                                                 NaN
# 12146                                                NaN
# 12611        Forge of Gods: Ultimate Titan Bundle bundle
# 12793  Digital Sound Factory: Session Drummer 3 Expan...
# 12879                                                NaN
# 19192  Battle vs Chess - Grandmaster Premium Edition ...
# 20193  Crazy Machines: Wacky Contraption Ultimate Col...
# 20457       Battle vs Chess - Grandmaster Edition bundle
# 20926            99 Spirits - Complete Collection bundle
# 21253  Warhammer 40,000: Dawn of War II - Retribution...
# 21303  The Incredible Adventures of Van Helsing Antho...
# 23099                                                NaN
# 25899                Krater - Collector's Edition bundle
# 28380                                                NaN
# 33730  Grab a wireless receiver (dongle) as a replace...
# 34365    Dragon's Prophet Yeniyıl Özel Paketi - 2 bundle
# 35169                                                NaN
# 39934                                                NaN
# 40235           Valve Index Headset + Controllers bundle
# 40238                          Valve Index VR Kit bundle
# 40248  VIVE is a first-of-its-kind virtual reality pl...
#
#                                           recent_reviews  \
# 146    Mostly Positive,(39),- 74% of the 39 user revi...
# 610                                                  NaN
# 704                                                  NaN
# 3410                                                 NaN
# 4847                                                 NaN
# 6381                                                 NaN
# 6710                                                 NaN
# 7869                                                 NaN
# 9015                                                 NaN
# 9016                                                 NaN
# 9371                                                 NaN
# 9372                                                 NaN
# 9375                                                 NaN
# 9615                                                 NaN
# 9616                                                 NaN
# 9956                                                 NaN
# 12146                                                NaN
# 12611                                                NaN
# 12793                                                NaN
# 12879                                                NaN
# 19192                                                NaN
# 20193                                                NaN
# 20457                                                NaN
# 20926                                                NaN
# 21253                                                NaN
# 21303                                                NaN
# 23099                                                NaN
# 25899                                                NaN
# 28380                                                NaN
# 33730                                                NaN
# 34365                                                NaN
# 35169                                                NaN
# 39934                                                NaN
# 40235                                                NaN
# 40238                                                NaN
# 40248                                                NaN
#
#                                              all_reviews  release_date  \
# 146    Mostly Positive,(7,942),- 73% of the 7,942 use...  Nov 10, 2015
# 610                                                  NaN           NaN
# 704                                                  NaN           NaN
# 3410                                                 NaN           NaN
# 4847                                                 NaN           NaN
# 6381                                                 NaN           NaN
# 6710                                                 NaN           NaN
# 7869                                                 NaN           NaN
# 9015                                                 NaN           NaN
# 9016                                                 NaN           NaN
# 9371                                                 NaN           NaN
# 9372                                                 NaN           NaN
# 9375                                                 NaN           NaN
# 9615                                                 NaN           NaN
# 9616                                                 NaN           NaN
# 9956                                                 NaN           NaN
# 12146                                                NaN           NaN
# 12611                                                NaN           NaN
# 12793                                                NaN           NaN
# 12879                                                NaN           NaN
# 19192                                                NaN           NaN
# 20193                                                NaN           NaN
# 20457                                                NaN           NaN
# 20926                                                NaN           NaN
# 21253                                                NaN           NaN
# 21303                                                NaN           NaN
# 23099                                                NaN           NaN
# 25899                                                NaN           NaN
# 28380                                                NaN           NaN
# 33730                                                NaN  Sep 29, 2016
# 34365                                                NaN           NaN
# 35169                                                NaN           NaN
# 39934                                                NaN           NaN
# 40235                                                NaN           NaN
# 40238                                                NaN           NaN
# 40248                                                NaN   Apr 5, 2016
#
#                         developer publisher  \
# 146                           NaN      None
# 610         The Creative Assembly      None
# 704                           NaN      None
# 3410            SimBin Studios AB      None
# 4847                          NaN      None
# 6381                          NaN      None
# 6710         Tripwire Interactive      None
# 7869                          NaN      None
# 9015                 Gaijin Games      None
# 9016                 Gaijin Games      None
# 9371          Relic Entertainment      None
# 9372   Monolith Productions, Inc.      None
# 9375          Relic Entertainment      None
# 9615                          NaN      None
# 9616                          NaN      None
# 9956                          NaN      None
# 12146                         NaN      None
# 12611                         NaN      None
# 12793                         NaN      None
# 12879                         NaN      None
# 19192                         NaN      None
# 20193               Fakt Software      None
# 20457                         NaN      None
# 20926                     TORaIKI      None
# 21253         Relic Entertainment      None
# 21303                NeocoreGames      None
# 23099                         NaN      None
# 25899                    Fatshark      None
# 28380                         NaN      None
# 33730                         NaN      None
# 34365                         NaN      None
# 35169                         NaN      None
# 39934                         NaN      None
# 40235                         NaN      None
# 40238                         NaN      None
# 40248                         NaN      None
#
#                                             popular_tags  \
# 146    Controller,Hardware,Steam Machine,Local Multip...
# 610                                                  NaN
# 704                                                  NaN
# 3410                                                 NaN
# 4847                                                 NaN
# 6381                                                 NaN
# 6710                                                 NaN
# 7869                                                 NaN
# 9015                                                 NaN
# 9016                                                 NaN
# 9371                                                 NaN
# 9372                                                 NaN
# 9375                                                 NaN
# 9615                                                 NaN
# 9616                                                 NaN
# 9956                                                 NaN
# 12146                                                NaN
# 12611                                                NaN
# 12793                                                NaN
# 12879                                                NaN
# 19192                                                NaN
# 20193                                                NaN
# 20457                                                NaN
# 20926                                                NaN
# 21253                                                NaN
# 21303                                                NaN
# 23099                                                NaN
# 25899                                                NaN
# 28380                                                NaN
# 33730                                           Hardware
# 34365                                                NaN
# 35169                                                NaN
# 39934                                                NaN
# 40235                                                NaN
# 40238                                                NaN
# 40248  VR,Hardware,Futuristic,First-Person,Simulation...
#
#                                             game_details languages  \
# 146                                                  NaN       NaN
# 610    Single-player,Multi-player,Downloadable Conten...       NaN
# 704                                                  NaN       NaN
# 3410     Single-player,Multi-player,Downloadable Content       NaN
# 4847                                                 NaN       NaN
# 6381                                                 NaN       NaN
# 6710   Single-player,Multi-player,Co-op,Cross-Platfor...       NaN
# 7869                                                 NaN       NaN
# 9015   Single-player,Downloadable Content,Steam Achie...       NaN
# 9016   Single-player,Downloadable Content,Steam Achie...       NaN
# 9371   Single-player,Multi-player,Co-op,Downloadable ...       NaN
# 9372   Single-player,Multi-player,Co-op,Downloadable ...       NaN
# 9375   Single-player,Multi-player,Co-op,Downloadable ...       NaN
# 9615                                                 NaN       NaN
# 9616                                                 NaN       NaN
# 9956                                                 NaN       NaN
# 12146                                                NaN       NaN
# 12611                                                NaN       NaN
# 12793                                                NaN       NaN
# 12879                                                NaN       NaN
# 19192                                                NaN       NaN
# 20193  Single-player,Multi-player,Downloadable Conten...       NaN
# 20457                                                NaN       NaN
# 20926  Single-player,Downloadable Content,Steam Achie...       NaN
# 21253  Single-player,Multi-player,Co-op,Downloadable ...       NaN
# 21303  Single-player,Multi-player,Co-op,Cross-Platfor...       NaN
# 23099                                                NaN       NaN
# 25899  Single-player,Co-op,Downloadable Content,Steam...       NaN
# 28380                                                NaN       NaN
# 33730                                                NaN       NaN
# 34365                                                NaN       NaN
# 35169                                                NaN       NaN
# 39934                                                NaN       NaN
# 40235                                                NaN       NaN
# 40238                                                NaN       NaN
# 40248                                                NaN       NaN
#
#        achievements                                genre  \
# 146             NaN                                Valve
# 610             NaN                             Strategy
# 704             NaN                                  NaN
# 3410            NaN             Racing,Simulation,Sports
# 4847            NaN                                  NaN
# 6381            NaN                                  NaN
# 6710            NaN                               Action
# 7869            NaN                                  NaN
# 9015            NaN                  Action,Casual,Indie
# 9016            NaN                         Action,Indie
# 9371            NaN                             Strategy
# 9372            NaN                               Action
# 9375            NaN                             Strategy
# 9615            NaN                                  NaN
# 9616            NaN                                  NaN
# 9956            NaN                                  NaN
# 12146           NaN                                  NaN
# 12611           NaN                                  NaN
# 12793           NaN                                  NaN
# 12879           NaN                                  NaN
# 19192           NaN                                  NaN
# 20193           NaN           Casual,Strategy,Simulation
# 20457           NaN                                  NaN
# 20926           NaN                  Adventure,Indie,RPG
# 21253           NaN                             Strategy
# 21303           NaN  Action,Adventure,Indie,RPG,Strategy
# 23099           NaN                                  NaN
# 25899           NaN  Action,Adventure,Indie,RPG,Strategy
# 28380           NaN                                  NaN
# 33730           NaN                                Valve
# 34365           NaN                                  NaN
# 35169           NaN                                  NaN
# 39934           NaN                                Valve
# 40235           NaN                                  NaN
# 40238           NaN                                  NaN
# 40248           NaN                                  HTC
#
#                                         game_description mature_content  \
# 146     About This Hardware Experience a new level of...            NaN
# 610                                                  NaN            NaN
# 704                                                  NaN            NaN
# 3410                                                 NaN            NaN
# 4847    About this bundle  Get all extra characters i...            NaN
# 6381    About this bundle  This bundle contains  thre...            NaN
# 6710                                                 NaN            NaN
# 7869                                                 NaN            NaN
# 9015                                                 NaN            NaN
# 9016                                                 NaN            NaN
# 9371                                                 NaN            NaN
# 9372                                                 NaN            NaN
# 9375                                                 NaN            NaN
# 9615    About this bundle  Happy Bat VR Bundle contai...            NaN
# 9616    About this bundle  Get the base game and all ...            NaN
# 9956    About this bundle  Benefit from -25% on this ...            NaN
# 12146          About this bundle  All Joe Papp content.             NaN
# 12611                                                NaN            NaN
# 12793                                                NaN            NaN
# 12879   About this bundle  The ultimate PSYCHO-PASS g...            NaN
# 19192                                                NaN            NaN
# 20193                                                NaN            NaN
# 20457                                                NaN            NaN
# 20926                                                NaN            NaN
# 21253                                                NaN            NaN
# 21303                                                NaN            NaN
# 23099   About this bundle  Game + DLC = Happy New Yea...            NaN
# 25899                                                NaN            NaN
# 28380   About this bundle  Purchase this bundle to sa...            NaN
# 33730   About This Hardware Grab a wireless receiver ...            NaN
# 34365                                                NaN            NaN
# 35169                                                NaN            NaN
# 39934        Reserve now to be notified of availabili...            NaN
# 40235                                                NaN            NaN
# 40238                                                NaN            NaN
# 40248   About This Hardware  VIVE is a first-of-its-k...            NaN
#
#                                     minimum_requirements  \
# 146                                                  NaN
# 610                                                  NaN
# 704                                                  NaN
# 3410                                                 NaN
# 4847                                                 NaN
# 6381                                                 NaN
# 6710                                                 NaN
# 7869                                                 NaN
# 9015                                                 NaN
# 9016                                                 NaN
# 9371                                                 NaN
# 9372                                                 NaN
# 9375                                                 NaN
# 9615                                                 NaN
# 9616                                                 NaN
# 9956                                                 NaN
# 12146                                                NaN
# 12611                                                NaN
# 12793                                                NaN
# 12879                                                NaN
# 19192                                                NaN
# 20193                                                NaN
# 20457                                                NaN
# 20926                                                NaN
# 21253                                                NaN
# 21303                                                NaN
# 23099                                                NaN
# 25899                                                NaN
# 28380                                                NaN
# 33730                                                NaN
# 34365                                                NaN
# 35169                                                NaN
# 39934  Minimum:,OS:,Windows 10,Processor:,Dual Core w...
# 40235                                                NaN
# 40238                                                NaN
# 40248                                                NaN
#
#                                 recommended_requirements original_price  \
# 146                                                  NaN         $49.99
# 610                                                  NaN         $24.99
# 704                                                  NaN         $29.99
# 3410                                                 NaN         $39.99
# 4847                                                 NaN            NaN
# 6381                                                 NaN            NaN
# 6710                                                 NaN         $39.99
# 7869                                                 NaN            NaN
# 9015                                                 NaN         $49.99
# 9016                                                 NaN         $16.99
# 9371                                                 NaN         $79.99
# 9372                                                 NaN         $54.99
# 9375                                                 NaN        $139.99
# 9615                                                 NaN            NaN
# 9616                                                 NaN            NaN
# 9956                                                 NaN            NaN
# 12146                                                NaN            NaN
# 12611                                                NaN            NaN
# 12793                                                NaN            NaN
# 12879                                                NaN            NaN
# 19192                                                NaN            NaN
# 20193                                                NaN         $49.99
# 20457                                                NaN            NaN
# 20926                                                NaN         $29.99
# 21253                                                NaN         $54.99
# 21303                                                NaN         $74.99
# 23099                                                NaN            NaN
# 25899                                                NaN         $29.99
# 28380                                                NaN            NaN
# 33730                                                NaN         $12.99
# 34365                                                NaN            NaN
# 35169                                                NaN            NaN
# 39934  Recommended:,Processor:,Quad Core +,Graphics:,...        $499.00
# 40235                                                NaN        $749.00
# 40238                                                NaN        $999.00
# 40248                                                NaN        $499.00
#
#       discount_price
# 146              NaN
# 610              NaN
# 704           $23.99
# 3410           $7.99
# 4847          $18.84
# 6381           $2.67
# 6710           $7.99
# 7869          $53.96
# 9015           $9.99
# 9016          $14.99
# 9371           $9.99
# 9372          $14.99
# 9375           $9.99
# 9615          $11.03
# 9616          $12.55
# 9956           $1.48
# 12146          $9.96
# 12611            NaN
# 12793            NaN
# 12879         $32.28
# 19192         $14.97
# 20193          $9.99
# 20457         $10.48
# 20926          $9.99
# 21253          $2.99
# 21303         $19.99
# 23099          $1.98
# 25899         $14.99
# 28380         $16.55
# 33730            NaN
# 34365         $98.58
# 35169            NaN
# 39934            NaN
# 40235            NaN
# 40238            NaN
# 40248            NaN

# %% [markdown]
# # Game Details

# %%
### creating a loop of all the different details, calculating the occurences to select the top used.
details = {}
# Stripping game details
df.game_details = df.game_details.str.strip()
for index, row in df.iterrows():
    details_list= str(row['game_details']).split(',')
    for detail in details_list:
        if not detail in details:
            details[detail] = 1
        else:
            details[detail] += 1

details_df = pd.DataFrame(list(details.items()),columns = ['game_details','count'])
details_df.sort_values('count', ascending =False)
# Out:
#                                          game_details  count
# 0                                       Single-player  36463
# 3                                  Steam Achievements  22045
# 14                               Downloadable Content  14815
# 4                                 Steam Trading Cards  13219
# 6                                         Steam Cloud  13155
# 15                            Full controller support  10012
# 1                                        Multi-player   9096
# 25                           Profile Features Limited   8443
# 5                          Partial Controller Support   7748
# 18                                 Steam Leaderboards   6801
# 2                                               Co-op   4865
# 7                                 Online Multi-Player   4522
# 17                                Shared/Split Screen   4360
# 8                                               Stats   2953
# 9                          Cross-Platform Multiplayer   2805
# 19                                 Local Multi-Player   2368
# 10                                     Steam Workshop   2329
# 29                  Steam is learning about this game   2260
# 13                                       Online Co-op   2151
# 21                              Includes level editor   1736
# 16                                        Local Co-op   1529
# 22                                   In-App Purchases   1492
# 20                                 Captions available   1275
# 12                                                MMO    886
# 27                                                nan    520
# 11                           Valve Anti-Cheat enabled    388
# 24                               Commentary available    246
# 32                                          Game demo    235
# 34  Steam is learning about this downloadable content    218
# 28                           Steam Turn Notifications    116
# 23                                Includes Source SDK     71
# 26                               SteamVR Collectibles     55
# 30              Steam is learning about this software     35
# 31                                               Mods      9
# 33                                 Mods (require HL2)      7

# %%
df[(df.game_details.isnull() == True) & (df.game_description.str.contains('About This Software') == False)]['url']
# Out:
# 146      https://store.steampowered.com/app/353370/Stea...
# 1705     https://store.steampowered.com/app/39530/Paink...
# 2202     https://store.steampowered.com/app/48220/Might...
# 3220     https://store.steampowered.com/app/976180/Deli...
# 3562     https://store.steampowered.com/app/36150/Westw...
#                                ...
# 40133    https://store.steampowered.com/app/795330/Robo...
# 40234    https://store.steampowered.com/app/404110/Work...
# 40248    https://store.steampowered.com/app/358040/HTC_...
# 40367    https://store.steampowered.com/app/442310/Fore...
# 40785    https://store.steampowered.com/app/914460/Init...
# Name: url, Length: 193, dtype: object

# %%
df[df.game_description.str.contains('About This Content') == True]
# Out:
#                                                      url types  \
# 827    https://store.steampowered.com/app/441340/Elit...   app
# 1772   https://store.steampowered.com/app/57600/Tropi...   app
# 2105   https://store.steampowered.com/app/9070/DOOM_3...   app
# 2376   https://store.steampowered.com/app/201310/X3_A...   app
# 3478   https://store.steampowered.com/app/8650/RACE_0...   app
# ...                                                  ...   ...
# 40827  https://store.steampowered.com/app/899835/Rock...   app
# 40828  https://store.steampowered.com/app/899836/Rock...   app
# 40829  https://store.steampowered.com/app/899832/Rock...   app
# 40830  https://store.steampowered.com/app/906840/Fant...   app
# 40831  https://store.steampowered.com/app/906635/Mega...   app
#
#                                                     name desc_snippet  \
# 827                Elite Dangerous: Horizons Season Pass          NaN
# 1772                           Tropico 3: Absolute Power          NaN
# 2105                         DOOM 3 Resurrection of Evil          NaN
# 2376                                  X3: Albion Prelude          NaN
# 3478   RACE 07: Andy Priaulx Crowne Plaza Raceway (Fr...          NaN
# ...                                                  ...          ...
# 40827  Rocksmith® 2014 Edition – Remastered – Sabaton...          NaN
# 40828  Rocksmith® 2014 Edition – Remastered – Sabaton...          NaN
# 40829  Rocksmith® 2014 Edition – Remastered – Stone T...          NaN
# 40830  Fantasy Grounds - Quests of Doom 4: A Midnight...          NaN
# 40831                       Mega Man X5 Sound Collection          NaN
#
#                                           recent_reviews  \
# 827    Mixed,(21),- 42% of the 21 user reviews in the...
# 1772                                                 NaN
# 2105                                                 NaN
# 2376                                                 NaN
# 3478                                                 NaN
# ...                                                  ...
# 40827                                                NaN
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
#
#                                              all_reviews  release_date  \
# 827    Mostly Positive,(1,082),- 76% of the 1,082 use...  Dec 15, 2015
# 1772   Very Positive,(223),- 94% of the 223 user revi...  May 17, 2010
# 2105   Very Positive,(338),- 84% of the 338 user revi...   Apr 3, 2005
# 2376   Very Positive,(1,042),- 92% of the 1,042 user ...  Dec 15, 2011
# 3478   Mixed,(56),- 62% of the 56 user reviews for th...  Jun 19, 2008
# ...                                                  ...           ...
# 40827                                                NaN  Feb 12, 2019
# 40828                                                NaN  Feb 12, 2019
# 40829                                                NaN   Feb 5, 2019
# 40830                                                NaN  Jul 31, 2018
# 40831                                                NaN  Jul 24, 2018
#
#                      developer              publisher  \
# 827      Frontier Developments  Frontier Developments
# 1772           Haemimont Games  Kalypso Media Digital
# 2105               id Software            id Software
# 2376                   Egosoft                Egosoft
# 3478                    SimBin                 SimBin
# ...                        ...                    ...
# 40827  Ubisoft - San Francisco                   None
# 40828  Ubisoft - San Francisco                   None
# 40829  Ubisoft - San Francisco                   None
# 40830      SmiteWorks USA, LLC                   None
# 40831          CAPCOM CO., LTD                   None
#
#                                             popular_tags  \
# 827    Space,Simulation,Massively Multiplayer,Action,...
# 1772   Simulation,Strategy,City Builder,Economy,Great...
# 2105   Action,FPS,Horror,Sci-fi,Dark,Atmospheric,Shoo...
# 2376   Space,Simulation,Sandbox,Sci-fi,Action,Trading...
# 3478                           Racing,Simulation,Shooter
# ...                                                  ...
# 40827                                  Casual,Simulation
# 40828                                  Casual,Simulation
# 40829                                  Casual,Simulation
# 40830  RPG,Indie,Strategy,Software,Turn-Based,Fantasy...
# 40831                                             Action
#
#                                             game_details  \
# 827    Single-player,Multi-player,MMO,Co-op,Downloada...
# 1772                  Single-player,Downloadable Content
# 2105   Single-player,Multi-player,Downloadable Conten...
# 2376   Single-player,Downloadable Content,Steam Achie...
# 3478                                Downloadable Content
# ...                                                  ...
# 40827  Single-player,Shared/Split Screen,Downloadable...
# 40828  Single-player,Shared/Split Screen,Downloadable...
# 40829  Single-player,Shared/Split Screen,Downloadable...
# 40830  Multi-player,Co-op,Cross-Platform Multiplayer,...
# 40831  Single-player,Downloadable Content,Steam Achie...
#
#                                                languages  achievements  \
# 827        English,French,German,Russian,Spanish - Spain           NaN
# 1772       English,French,German,Italian,Spanish - Spain           NaN
# 2105                                             English           NaN
# 2376   English,French,German,Italian,Russian,Polish,S...          33.0
# 3478       English,French,German,Italian,Spanish - Spain           NaN
# ...                                                  ...           ...
# 40827  English,German,French,Italian,Spanish - Spain,...           NaN
# 40828  English,German,French,Italian,Spanish - Spain,...           NaN
# 40829  English,German,French,Italian,Spanish - Spain,...           NaN
# 40830                                            English           NaN
# 40831  English,French,Italian,German,Spanish - Spain,...           NaN
#
#                                                    genre  \
# 827    Action,Adventure,Massively Multiplayer,RPG,Sim...
# 1772                                 Simulation,Strategy
# 2105                                              Action
# 2376                                   Action,Simulation
# 3478                                              Racing
# ...                                                  ...
# 40827                                  Casual,Simulation
# 40828                                  Casual,Simulation
# 40829                                  Casual,Simulation
# 40830                                 Indie,RPG,Strategy
# 40831                                             Action
#
#                                         game_description mature_content  \
# 827     About This Content Change the galaxy with the...            NaN
# 1772    About This Content  Tropico 3: Absolute Power...            NaN
# 2105    About This Content  The gripping expansion pa...            NaN
# 2376    About This Content X3: Albion Prelude is the ...            NaN
# 3478    About This Content Blue skies and white beach...            NaN
# ...                                                  ...            ...
# 40827   About This Content Play "Primo Victoria" by S...            NaN
# 40828   About This Content Play "Ghost Division" by S...            NaN
# 40829   About This Content Play "Trippin’ on a Hole i...            NaN
# 40830   About This Content  Quests of Doom 4: A Midni...            NaN
# 40831   About This Content Get equipped with the stun...            NaN
#
#                                     minimum_requirements  \
# 827    Minimum:,OS:,Windows 7/8/10 64-bit,Processor:,...
# 1772                                                 NaN
# 2105                                                 NaN
# 2376   Minimum:,OS:,Windows 10 / 8 / 7 / Vista SP1 / ...
# 3478                                                 NaN
# ...                                                  ...
# 40827  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40828  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40829  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40830  Minimum:,OS:,Windows 7x , 8x or 10x,Processor:...
# 40831  Minimum:,OS:,WINDOWS® 7 (64bit),Processor:,Int...
#
#                                 recommended_requirements original_price  \
# 827    Recommended:,OS:,Windows 7/8/10 64-bit,Process...         $29.99
# 1772                                                 NaN          $9.99
# 2105                                                 NaN          $2.99
# 2376   Recommended:,OS:,Windows 10 / 8 / 7 / Vista SP...          $9.99
# 3478                                                 NaN         $39.99
# ...                                                  ...            ...
# 40827  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40828  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40829  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40830  Recommended:,OS:,Windows 7x , 8x or 10x,Proces...          $7.99
# 40831  Recommended:,OS:,WINDOWS®10 (64bit),Processor:...          $9.99
#
#       discount_price
# 827          $320.94
# 1772         $115.97
# 2105           $1.79
# 2376             NaN
# 3478             NaN
# ...              ...
# 40827            NaN
# 40828            NaN
# 40829            NaN
# 40830            NaN
# 40831            NaN
#
# [13111 rows x 20 columns]

# %% [markdown]
# # Achievements

# %%
df[df.achievements.isnull() == True]
# Out:
#                                                      url   types  \
# 3        https://store.steampowered.com/app/221100/DayZ/     app
# 4      https://store.steampowered.com/app/8500/EVE_On...     app
# 5      https://store.steampowered.com/bundle/5699/Gra...  bundle
# 12       https://store.steampowered.com/app/323370/TERA/     app
# 14     https://store.steampowered.com/app/253250/Ston...     app
# ...                                                  ...     ...
# 40828  https://store.steampowered.com/app/899836/Rock...     app
# 40829  https://store.steampowered.com/app/899832/Rock...     app
# 40830  https://store.steampowered.com/app/906840/Fant...     app
# 40831  https://store.steampowered.com/app/906635/Mega...     app
# 40832  https://store.steampowered.com/app/908000/Stor...     app
#
#                                                     name  \
# 3                                                   DayZ
# 4                                             EVE Online
# 5             Grand Theft Auto V: Premium Online Edition
# 12                                                  TERA
# 14                                           Stonehearth
# ...                                                  ...
# 40828  Rocksmith® 2014 Edition – Remastered – Sabaton...
# 40829  Rocksmith® 2014 Edition – Remastered – Stone T...
# 40830  Fantasy Grounds - Quests of Doom 4: A Midnight...
# 40831                       Mega Man X5 Sound Collection
# 40832                                   Stories In Stone
#
#                                             desc_snippet  \
# 3      The post-soviet country of Chernarus is struck...
# 4      EVE Online is a community-driven spaceship MMO...
# 5      Grand Theft Auto V: Premium Online Edition bundle
# 12     From En Masse Entertainment, TERA is at the fo...
# 14     Pioneer a living world full of warmth, heroism...
# ...                                                  ...
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
# 40832  An RPG about a tribe exploring an ancient worl...
#
#                                           recent_reviews  \
# 3      Mixed,(932),- 57% of the 932 user reviews in t...
# 4      Mixed,(287),- 54% of the 287 user reviews in t...
# 5                                                    NaN
# 12     Mixed,(76),- 63% of the 76 user reviews in the...
# 14     Mixed,(66),- 40% of the 66 user reviews in the...
# ...                                                  ...
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
# 40832                                                NaN
#
#                                              all_reviews  release_date  \
# 3      Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4      Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
# 5                                                    NaN           NaN
# 12     Mostly Positive,(14,184),- 78% of the 14,184 u...   May 5, 2015
# 14     Mostly Positive,(5,484),- 75% of the 5,484 use...  Jul 25, 2018
# ...                                                  ...           ...
# 40828                                                NaN  Feb 12, 2019
# 40829                                                NaN   Feb 5, 2019
# 40830                                                NaN  Jul 31, 2018
# 40831                                                NaN  Jul 24, 2018
# 40832                                                NaN   Aug 8, 2018
#
#                      developer               publisher  \
# 3          Bohemia Interactive     Bohemia Interactive
# 4                          CCP                     CCP
# 5               Rockstar North                    None
# 12              Bluehole, Inc.  En Masse Entertainment
# 14       Radiant Entertainment                  (none)
# ...                        ...                     ...
# 40828  Ubisoft - San Francisco                    None
# 40829  Ubisoft - San Francisco                    None
# 40830      SmiteWorks USA, LLC                    None
# 40831          CAPCOM CO., LTD                    None
# 40832      16 Bit Psych,Kyle B            Self-Publish
#
#                                             popular_tags  \
# 3      Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4      Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
# 5                                                    NaN
# 12     Free to Play,MMORPG,Massively Multiplayer,RPG,...
# 14     City Builder,Building,Sandbox,Strategy,Surviva...
# ...                                                  ...
# 40828                                  Casual,Simulation
# 40829                                  Casual,Simulation
# 40830  RPG,Indie,Strategy,Software,Turn-Based,Fantasy...
# 40831                                             Action
# 40832                                      RPG,Adventure
#
#                                             game_details  \
# 3      Multi-player,Online Multi-Player,Steam Worksho...
# 4      Multi-player,Online Multi-Player,MMO,Co-op,Onl...
# 5      Single-player,Multi-player,Downloadable Conten...
# 12     Multi-player,MMO,Co-op,Steam Trading Cards,Par...
# 14     Single-player,Multi-player,Online Multi-Player...
# ...                                                  ...
# 40828  Single-player,Shared/Split Screen,Downloadable...
# 40829  Single-player,Shared/Split Screen,Downloadable...
# 40830  Multi-player,Co-op,Cross-Platform Multiplayer,...
# 40831  Single-player,Downloadable Content,Steam Achie...
# 40832  Single-player,Partial Controller Support,Profi...
#
#                                                languages  achievements  \
# 3      English,French,Italian,German,Spanish - Spain,...           NaN
# 4                          English,German,Russian,French           NaN
# 5      English, French, Italian, German, Spanish - Sp...           NaN
# 12                                               English           NaN
# 14                                               English           NaN
# ...                                                  ...           ...
# 40828  English,German,French,Italian,Spanish - Spain,...           NaN
# 40829  English,German,French,Italian,Spanish - Spain,...           NaN
# 40830                                            English           NaN
# 40831  English,French,Italian,German,Spanish - Spain,...           NaN
# 40832                                            English           NaN
#
#                                                    genre  \
# 3                 Action,Adventure,Massively Multiplayer
# 4      Action,Free to Play,Massively Multiplayer,RPG,...
# 5                                       Action,Adventure
# 12     Action,Adventure,Free to Play,Massively Multip...
# 14                             Indie,Simulation,Strategy
# ...                                                  ...
# 40828                                  Casual,Simulation
# 40829                                  Casual,Simulation
# 40830                                 Indie,RPG,Strategy
# 40831                                             Action
# 40832                                      Adventure,RPG
#
#                                         game_description  \
# 3       About This Game The post-soviet country of Ch...
# 4                                      About This Game
# 5                                                    NaN
# 12      About This Game  TERA is at the forefront of ...
# 14      About This Game In Stonehearth, you pioneer a...
# ...                                                  ...
# 40828   About This Content Play "Ghost Division" by S...
# 40829   About This Content Play "Trippin’ on a Hole i...
# 40830   About This Content  Quests of Doom 4: A Midni...
# 40831   About This Content Get equipped with the stun...
# 40832   About This Game  An RPG about a tribe explori...
#
#                                           mature_content  \
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 12      Mature Content Description  The developers de...
# 14                                                   NaN
# ...                                                  ...
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
# 40832                                                NaN
#
#                                     minimum_requirements  \
# 3      Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4      Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
# 5                                                    NaN
# 12     Minimum:,OS:,Windows 7, 32-bit,Processor:,Inte...
# 14     Minimum:,OS:,Windows 7/8/8.1/10 (32-bit or 64-...
# ...                                                  ...
# 40828  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40829  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40830  Minimum:,OS:,Windows 7x , 8x or 10x,Processor:...
# 40831  Minimum:,OS:,WINDOWS® 7 (64bit),Processor:,Int...
# 40832                                                NaN
#
#                                 recommended_requirements original_price  \
# 3      Recommended:,OS:,Windows 10 64-bit,Processor:,...         $44.99
# 4      Recommended:,OS:,Windows 10,Processor:,Intel i...           Free
# 5                                                    NaN            NaN
# 12     Recommended:,OS:,Windows 7, 8, 8.1, 10, 64-bit...   Free to Play
# 14     Recommended:,OS:,Windows 10,Processor:,Intel o...         $19.99
# ...                                                  ...            ...
# 40828  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40829  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40830  Recommended:,OS:,Windows 7x , 8x or 10x,Proces...          $7.99
# 40831  Recommended:,OS:,WINDOWS®10 (64bit),Processor:...          $9.99
# 40832                                                NaN          $4.99
#
#       discount_price
# 3                NaN
# 4                NaN
# 5             $35.18
# 12               NaN
# 14               NaN
# ...              ...
# 40828            NaN
# 40829            NaN
# 40830            NaN
# 40831            NaN
# 40832          $2.80
#
# [28639 rows x 20 columns]

# %%
import math
#categorization 
for i in df.index:
    df.at[i, 'achievement_cat'] = 0 if math.isnan(df.loc[i]['achievements']) == True else 1

# %%
df
# Out:
#                                                      url types  \
# 0        https://store.steampowered.com/app/379720/DOOM/   app
# 1      https://store.steampowered.com/app/578080/PLAY...   app
# 2      https://store.steampowered.com/app/637090/BATT...   app
# 3        https://store.steampowered.com/app/221100/DayZ/   app
# 4      https://store.steampowered.com/app/8500/EVE_On...   app
# ...                                                  ...   ...
# 40828  https://store.steampowered.com/app/899836/Rock...   app
# 40829  https://store.steampowered.com/app/899832/Rock...   app
# 40830  https://store.steampowered.com/app/906840/Fant...   app
# 40831  https://store.steampowered.com/app/906635/Mega...   app
# 40832  https://store.steampowered.com/app/908000/Stor...   app
#
#                                                     name  \
# 0                                                   DOOM
# 1                          PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                                             BATTLETECH
# 3                                                   DayZ
# 4                                             EVE Online
# ...                                                  ...
# 40828  Rocksmith® 2014 Edition – Remastered – Sabaton...
# 40829  Rocksmith® 2014 Edition – Remastered – Stone T...
# 40830  Fantasy Grounds - Quests of Doom 4: A Midnight...
# 40831                       Mega Man X5 Sound Collection
# 40832                                   Stories In Stone
#
#                                             desc_snippet  \
# 0      Now includes all three premium DLC packs (Unto...
# 1      PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2      Take command of your own mercenary outfit of '...
# 3      The post-soviet country of Chernarus is struck...
# 4      EVE Online is a community-driven spaceship MMO...
# ...                                                  ...
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
# 40832  An RPG about a tribe exploring an ancient worl...
#
#                                           recent_reviews  \
# 0      Very Positive,(554),- 89% of the 554 user revi...
# 1      Mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2      Mixed,(166),- 54% of the 166 user reviews in t...
# 3      Mixed,(932),- 57% of the 932 user reviews in t...
# 4      Mixed,(287),- 54% of the 287 user reviews in t...
# ...                                                  ...
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
# 40832                                                NaN
#
#                                              all_reviews  release_date  \
# 0      Very Positive,(42,550),- 92% of the 42,550 use...  May 12, 2016
# 1      Mixed,(836,608),- 49% of the 836,608 user revi...  Dec 21, 2017
# 2      Mostly Positive,(7,030),- 71% of the 7,030 use...  Apr 24, 2018
# 3      Mixed,(167,115),- 61% of the 167,115 user revi...  Dec 13, 2018
# 4      Mostly Positive,(11,481),- 74% of the 11,481 u...   May 6, 2003
# ...                                                  ...           ...
# 40828                                                NaN  Feb 12, 2019
# 40829                                                NaN   Feb 5, 2019
# 40830                                                NaN  Jul 31, 2018
# 40831                                                NaN  Jul 24, 2018
# 40832                                                NaN   Aug 8, 2018
#
#                      developer            publisher  \
# 0                  id Software   Bethesda Softworks
# 1             PUBG Corporation     PUBG Corporation
# 2          Harebrained Schemes  Paradox Interactive
# 3          Bohemia Interactive  Bohemia Interactive
# 4                          CCP                  CCP
# ...                        ...                  ...
# 40828  Ubisoft - San Francisco                 None
# 40829  Ubisoft - San Francisco                 None
# 40830      SmiteWorks USA, LLC                 None
# 40831          CAPCOM CO., LTD                 None
# 40832      16 Bit Psych,Kyle B         Self-Publish
#
#                                             popular_tags  ...  \
# 0      FPS,Gore,Action,Demons,Shooter,First-Person,Gr...  ...
# 1      Survival,Shooter,Multiplayer,Battle Royale,PvP...  ...
# 2      Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...  ...
# 3      Survival,Zombies,Open World,Multiplayer,PvP,Ma...  ...
# 4      Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...  ...
# ...                                                  ...  ...
# 40828                                  Casual,Simulation  ...
# 40829                                  Casual,Simulation  ...
# 40830  RPG,Indie,Strategy,Software,Turn-Based,Fantasy...  ...
# 40831                                             Action  ...
# 40832                                      RPG,Adventure  ...
#
#                                                languages achievements  \
# 0      English,French,Italian,German,Spanish - Spain,...         54.0
# 1      English,Korean,Simplified Chinese,French,Germa...         37.0
# 2                          English,French,German,Russian        128.0
# 3      English,French,Italian,German,Spanish - Spain,...          NaN
# 4                          English,German,Russian,French          NaN
# ...                                                  ...          ...
# 40828  English,German,French,Italian,Spanish - Spain,...          NaN
# 40829  English,German,French,Italian,Spanish - Spain,...          NaN
# 40830                                            English          NaN
# 40831  English,French,Italian,German,Spanish - Spain,...          NaN
# 40832                                            English          NaN
#
#                                                    genre  \
# 0                                                 Action
# 1                 Action,Adventure,Massively Multiplayer
# 2                              Action,Adventure,Strategy
# 3                 Action,Adventure,Massively Multiplayer
# 4      Action,Free to Play,Massively Multiplayer,RPG,...
# ...                                                  ...
# 40828                                  Casual,Simulation
# 40829                                  Casual,Simulation
# 40830                                 Indie,RPG,Strategy
# 40831                                             Action
# 40832                                      Adventure,RPG
#
#                                         game_description  \
# 0       About This Game Developed by id software, the...
# 1       About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2       About This Game  From original BATTLETECH/Mec...
# 3       About This Game The post-soviet country of Ch...
# 4                                      About This Game
# ...                                                  ...
# 40828   About This Content Play "Ghost Division" by S...
# 40829   About This Content Play "Trippin’ on a Hole i...
# 40830   About This Content  Quests of Doom 4: A Midni...
# 40831   About This Content Get equipped with the stun...
# 40832   About This Game  An RPG about a tribe explori...
#
#                                           mature_content  \
# 0                                                    NaN
# 1       Mature Content Description  The developers de...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40828                                                NaN
# 40829                                                NaN
# 40830                                                NaN
# 40831                                                NaN
# 40832                                                NaN
#
#                                     minimum_requirements  \
# 0      Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 1      Minimum:,Requires a 64-bit processor and opera...
# 2      Minimum:,Requires a 64-bit processor and opera...
# 3      Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4      Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
# ...                                                  ...
# 40828  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40829  Minimum:,OS:,Windows Vista, Windows 7, Windows...
# 40830  Minimum:,OS:,Windows 7x , 8x or 10x,Processor:...
# 40831  Minimum:,OS:,WINDOWS® 7 (64bit),Processor:,Int...
# 40832                                                NaN
#
#                                 recommended_requirements original_price  \
# 0      Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...         $19.99
# 1      Recommended:,Requires a 64-bit processor and o...         $29.99
# 2      Recommended:,Requires a 64-bit processor and o...         $39.99
# 3      Recommended:,OS:,Windows 10 64-bit,Processor:,...         $44.99
# 4      Recommended:,OS:,Windows 10,Processor:,Intel i...           Free
# ...                                                  ...            ...
# 40828  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40829  Recommended:,OS:,Windows Vista, Windows 7, Win...          $2.99
# 40830  Recommended:,OS:,Windows 7x , 8x or 10x,Proces...          $7.99
# 40831  Recommended:,OS:,WINDOWS®10 (64bit),Processor:...          $9.99
# 40832                                                NaN          $4.99
#
#       discount_price achievement_cat
# 0             $14.99               1
# 1                NaN               1
# 2                NaN               1
# 3                NaN               0
# 4                NaN               0
# ...              ...             ...
# 40828            NaN               0
# 40829            NaN               0
# 40830            NaN               0
# 40831            NaN               0
# 40832          $2.80               0
#
# [40833 rows x 21 columns]

# %% [markdown]
# # Scrapping missing data

# %% [markdown]
# ## Developpers

# %%
df_app = df[df['types'] == 'app']
df_app['types'].value_counts()
# Out:
# app    38021
# Name: types, dtype: int64

# %%
df_app[df['developer'].isnull() == True]['url']
# Out:
# /var/folders/dv/7t_6tkbx07s6mfq_r5jxkp240000gp/T/ipykernel_25097/1181569292.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_app[df['developer'].isnull() == True]['url']
# 146      https://store.steampowered.com/app/353370/Stea...
# 1101     https://store.steampowered.com/app/239350/Spel...
# 1854     https://store.steampowered.com/app/247350/Arte...
# 2517     https://store.steampowered.com/app/243040/Star...
# 2712     https://store.steampowered.com/app/242550/Raym...
#                                ...
# 40133    https://store.steampowered.com/app/795330/Robo...
# 40234    https://store.steampowered.com/app/404110/Work...
# 40248    https://store.steampowered.com/app/358040/HTC_...
# 40266    https://store.steampowered.com/app/790770/Juve...
# 40785    https://store.steampowered.com/app/914460/Init...
# Name: url, Length: 300, dtype: object

# %%
from bs4 import BeautifulSoup
import requests
def get_dev(url):
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")
    try: 
        return soup.find('div', id='developers_list').text.strip().split(',')[0]
    except:
        return float('nan')

# %%
url =' https://store.steampowered.com/app/242550/Rayman_Legends/'

# %%
get_dev(url)
# Out:
# nan

# %%
temp = df_app[df_app['developer'].isnull() == True]

# %%
for index in temp.index:
    df_app.loc[index, 'developer'] = get_dev(df_app.loc[index, 'url'])
    print(index)
# Out:
# 146
# 1101
# 1854
# 2517
# 2712
# 3471
# 3989
# 4722
# 4847
# 4854
# 4933
# 4958
# 5344
# 5582
# 6026
# 6038
# 6133
# 6381
# 6518
# 6577
# 6899
# 7007
# 7678
# 7865
# 7869
# 7876
# 8284
# 8851
# 8888
# 9128
# 9431
# 9615
# 9616
# 9956
# 9984
# 11620
# 11633
# 11635
# 11636
# 11637
# 11696
# 11757
# 12097
# 12146
# 12429
# 12805
# 12879
# 13375
# 13643
# 13908
# 13926
# 14015
# 14272
# 14953
# 15159
# 15195
# 15277
# 15395
# 15619
# 15780
# 16042
# 16084
# 16283
# 16363
# 16364
# 16365
# 16465
# 16533
# 16606
# 17095
# 17436
# 17916
# 17917
# 17918
# 18003
# 18038
# 18043
# 18280
# 18353
# 18426
# 18568
# 18569
# 18570
# 18656
# 19040
# 19210
# 19471
# 20559
# 20599
# 20750
# 20872
# 21099
# 21242
# 21506
# 21511
# 21857
# 22364
# 22399
# 22542
# 22543
# 22917
# 22948
# 22950
# 22956
# 22966
# 23099
# 23282
# 23337
# 23592
# 23693
# 24228
# 24354
# 24877
# 24889
# 25195
# 25223
# 25255
# 25371
# 25433
# 25527
# 25558
# 25580
# 25583
# 25608
# 25716
# 25762
# 25860
# 25951
# 26025
# 26073
# 26080
# 26106
# 26122
# 26296
# 26735
# 26736
# 26737
# 26765
# 27095
# 27113
# 27147
# 27710
# 27732
# 28199
# 28252
# 28258
# 28380
# 28414
# 28682
# 28707
# 28731
# 28757
# 28766
# 28793
# 28808
# 29140
# 29243
# 29586
# 29760
# 29979
# 30042
# 30246
# 30248
# 30293
# 30608
# 30951
# 30962
# 30963
# 30964
# 30965
# 30973
# 31152
# 31154
# 31170
# 31231
# 31321
# 31406
# 31521
# 32003
# 32004
# 32006
# 32059
# 32259
# 32363
# 33102
# 33103
# 33105
# 33233
# 33300
# 33301
# 33368
# 33450
# 33451
# 33458
# 33611
# 33730
# 33952
# 33970
# 33971
# 33972
# 33973
# 33974
# 33976
# 34058
# 34301
# 34304
# 34337
# 34482
# 34483
# 34484
# 34548
# 34726
# 34730
# 34731
# 34858
# 34859
# 34879
# 34880
# 34881
# 34959
# 34961
# 34963
# 34989
# 34991
# 34997
# 34998
# 34999
# 35000
# 35001
# 35002
# 35108
# 35475
# 35476
# 35477
# 35478
# 35479
# 36095
# 36096
# 36097
# 36098
# 36099
# 36535
# 36584
# 36585
# 36586
# 36587
# 36589
# 36590
# 36857
# 36885
# 36914
# 37005
# 37006
# 37007
# 37009
# 37176
# 37178
# 37225
# 37226
# 37227
# 37229
# 37337
# 37340
# 37447
# 37835
# 37837
# 37915
# 37931
# 38036
# 38039
# 38040
# 38088
# 38372
# 38509
# 38512
# 38606
# 38687
# 38830
# 38919
# 39037
# 39038
# 39042
# 39100
# 39153
# 39158
# 39159
# 39160
# 39269
# 39457
# 39458
# 39575
# 39679
# 39680
# 39706
# 39934
# 40133
# 40234
# 40248
# 40266
# 40785

# %%
df_app[df_app['developer'].isnull() == True]['url']
# Out:
# 146      https://store.steampowered.com/app/353370/Stea...
# 1854     https://store.steampowered.com/app/247350/Arte...
# 2712     https://store.steampowered.com/app/242550/Raym...
# 3471     https://store.steampowered.com/app/664950/Dead...
# 3989     https://store.steampowered.com/app/253920/Gork...
#                                ...
# 40133    https://store.steampowered.com/app/795330/Robo...
# 40234    https://store.steampowered.com/app/404110/Work...
# 40248    https://store.steampowered.com/app/358040/HTC_...
# 40266    https://store.steampowered.com/app/790770/Juve...
# 40785    https://store.steampowered.com/app/914460/Init...
# Name: url, Length: 288, dtype: object

# %% [markdown]
# ## Publishers

# %%
def get_pub(url):
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")
    try: 
        return soup.find_all('div', class_='summary column')[3].find('a').string.strip().split(',')[0]
    except:
        return float('nan')

# %%
df_app[df_app['publisher'].isnull() == True]

# %%
url = 'https://store.steampowered.com/app/379720/DOOM/'

# %%
get_pub(url)

# %%
temp = df_app[df_app['publisher'].isnull() == True]

# %%
temp['url']

# %%
get_pub('https://store.steampowered.com/app/372000/Tree_of_Savior_English_Ver/')

# %%
for index in temp.index:
    df_app.loc[index, 'publisher'] = get_pub(df_app.loc[index, 'url'])
    print(index)

# %% [markdown]
# ## Popular tags

# %%
temp = df_app[df_app['popular_tags'].isnull() == True]

# %%
temp['url']
# Out:
# 1433     https://store.steampowered.com/app/33229/Tom_C...
# 4847     https://store.steampowered.com/bundle/6191/The...
# 6027     https://store.steampowered.com/app/40200/ItzaB...
# 6381     https://store.steampowered.com/bundle/7125/Fac...
# 7869     https://store.steampowered.com/bundle/10241/Da...
#                                ...
# 38333    https://store.steampowered.com/app/731900/Mast...
# 38835    https://store.steampowered.com/app/812030/Solo...
# 38836    https://store.steampowered.com/app/400810/Arca...
# 39934    https://store.steampowered.com/app/1059530/Val...
# 40729    https://store.steampowered.com/app/876500/Hype...
# Name: url, Length: 133, dtype: object

# %%
def get_tags(url):
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")
    try: 
        return ','.join([tag.text.strip() for tag in soup.find_all('a', class_='app_tag')])
    except:
        return float('nan')

# %%
url = 'https://store.steampowered.com/app/39530/Painkiller_Black_Edition/'
get_tags(url)
# Out:
# 'Gore,Action,FPS,Classic,Shooter,Great Soundtrack,First-Person,Singleplayer,Arena Shooter,Demons,Horror,Atmospheric,Fast-Paced,Gothic,Multiplayer,Zombies,Cult Classic,Dark,Old School'

# %%
for index in temp.index:
    df_app.loc[index, 'popular_tags'] = get_tags(df_app.loc[index, 'url'])
    print(index)
df_app['popular_tags'] = df_app['popular_tags'].replace('', float('nan'))
# Out:
# 1433
# 4847
# 6027
# 6381
# 7869
# 9615
# 9616
# 9956
# 10498
# 10649
# 10664
# 11206
# 11377
# 11379
# 11814
# 11940
# 11942
# 12146
# 12508
# 12648
# 12663
# 12698
# 12879
# 13206
# 13213
# 13354
# 13643
# 13908
# 13967
# 14104
# 14272
# 14619
# 14702
# 14763
# 15580
# 15619
# 15635
# 15637
# 15740
# 15836
# 16082
# 16139
# 16583
# 17028
# 17374
# 17437
# 18580
# 19396
# 19660
# 19996
# 20268
# 21321
# 21642
# 22442
# 22948
# 23009
# 23050
# 23099
# 23414
# 23562
# 24129
# 24531
# 25036
# 25255
# 26195
# 27069
# 27732
# 27845
# 28380
# 28949
# 30036
# 30973
# 30993
# 31218
# 31227
# 31369
# 31615
# 31754
# 31830
# 32003
# 32004
# 32006
# 32041
# 32045
# 32259
# 32363
# 32633
# 32673
# 33233
# 33970
# 33971
# 33972
# 33973
# 33974
# 33976
# 34057
# 34091
# 34092
# 34271
# 34357
# 34548
# 34565
# 34566
# 34567
# 34568
# 34569
# 34608
# 34726
# 34969
# 34989
# 34991
# 35132
# 35158
# 35159
# 35160
# 35161
# 35244
# 35246
# 35384
# 35452
# 35453
# 35527
# 36381
# 37251
# 37393
# 37394
# 37447
# 37476
# 38333
# 38835
# 38836
# 39934
# 40729

# %%
df_app[df_app['popular_tags'].isnull()]
# Out:
#                                                      url types  \
# 4847   https://store.steampowered.com/bundle/6191/The...   app
# 6381   https://store.steampowered.com/bundle/7125/Fac...   app
# 7869   https://store.steampowered.com/bundle/10241/Da...   app
# 9615   https://store.steampowered.com/bundle/8069/Hap...   app
# 9616   https://store.steampowered.com/bundle/7988/Scr...   app
# ...                                                  ...   ...
# 37476  https://store.steampowered.com/app/519210/Dayl...   app
# 38333  https://store.steampowered.com/app/731900/Mast...   app
# 38835  https://store.steampowered.com/app/812030/Solo...   app
# 38836  https://store.steampowered.com/app/400810/Arca...   app
# 39934  https://store.steampowered.com/app/1059530/Val...   app
#
#                                         name desc_snippet recent_reviews  \
# 4847                                     NaN          NaN            NaN
# 6381                                     NaN          NaN            NaN
# 7869                                     NaN          NaN            NaN
# 9615                                     NaN          NaN            NaN
# 9616                                     NaN          NaN            NaN
# ...                                      ...          ...            ...
# 37476  Daylight's End VR Edition - Chapter 1          NaN            NaN
# 38333   Master Project - 《Classical Rewrite》          NaN            NaN
# 38835             Solo - Original Soundtrack          NaN            NaN
# 38836                      Arcane Units Pack          NaN            NaN
# 39934                    Valve Index Headset          NaN            NaN
#
#       all_reviews  release_date             developer        publisher  \
# 4847          NaN           NaN                   NaN             None
# 6381          NaN           NaN                   NaN             None
# 7869          NaN           NaN                   NaN             None
# 9615          NaN           NaN                   NaN             None
# 9616          NaN           NaN                   NaN             None
# ...           ...           ...                   ...              ...
# 37476         NaN  Aug 26, 2016      Groove Jones LLC             None
# 38333         NaN  Jan 20, 2018       Extra Dimension  Extra Dimension
# 38835         NaN  Apr 26, 2018           Team Gotham      Team Gotham
# 38836         NaN  Feb 15, 2016  The Conjurer's Tower             None
# 39934         NaN           NaN                   NaN             None
#
#       popular_tags  ...                                   languages  \
# 4847           NaN  ...                                         NaN
# 6381           NaN  ...                                         NaN
# 7869           NaN  ...                                         NaN
# 9615           NaN  ...                                         NaN
# 9616           NaN  ...                                         NaN
# ...            ...  ...                                         ...
# 37476          NaN  ...                                     English
# 38333          NaN  ...                  English,Simplified Chinese
# 38835          NaN  ...  English,Spanish - Spain,Simplified Chinese
# 38836          NaN  ...                                     English
# 39934          NaN  ...                                         NaN
#
#       achievements            genre  \
# 4847           NaN              NaN
# 6381           NaN              NaN
# 7869           NaN              NaN
# 9615           NaN              NaN
# 9616           NaN              NaN
# ...            ...              ...
# 37476          NaN              NaN
# 38333          NaN              NaN
# 38835          NaN  Adventure,Indie
# 38836          NaN              NaN
# 39934          NaN            Valve
#
#                                         game_description mature_content  \
# 4847    About this bundle  Get all extra characters i...            NaN
# 6381    About this bundle  This bundle contains  thre...            NaN
# 7869                                                 NaN            NaN
# 9615    About this bundle  Happy Bat VR Bundle contai...            NaN
# 9616    About this bundle  Get the base game and all ...            NaN
# ...                                                  ...            ...
# 37476   About This Content Chapter 1: THE HUNTER - Ru...            NaN
# 38333   About This Content  《Classical Rewrite》is a a...            NaN
# 38835   About This Content 01.- The winds of whispers...            NaN
# 38836   About This Content Adds 6 new units to the ga...            NaN
# 39934        Reserve now to be notified of availabili...            NaN
#
#                                     minimum_requirements  \
# 4847                                                 NaN
# 6381                                                 NaN
# 7869                                                 NaN
# 9615                                                 NaN
# 9616                                                 NaN
# ...                                                  ...
# 37476                                                NaN
# 38333  Minimum:,OS:,>= Windows 7,Processor:,Intel Cor...
# 38835                                                NaN
# 38836                                                NaN
# 39934  Minimum:,OS:,Windows 10,Processor:,Dual Core w...
#
#                                 recommended_requirements original_price  \
# 4847                                                 NaN            NaN
# 6381                                                 NaN            NaN
# 7869                                                 NaN            NaN
# 9615                                                 NaN            NaN
# 9616                                                 NaN            NaN
# ...                                                  ...            ...
# 37476                                                NaN          $0.99
# 38333  Recommended:,OS:,>= Windows 7,Processor:,Intel...          $1.99
# 38835                                                NaN          $4.99
# 38836                                                NaN          $0.99
# 39934  Recommended:,Processor:,Quad Core +,Graphics:,...        $499.00
#
#       discount_price achievement_cat
# 4847          $18.84               0
# 6381           $2.67               0
# 7869          $53.96               0
# 9615          $11.03               0
# 9616          $12.55               0
# ...              ...             ...
# 37476         $12.25               0
# 38333            NaN               0
# 38835         $16.98               0
# 38836            NaN               0
# 39934            NaN               0
#
# [102 rows x 21 columns]

# %% [markdown]
# ## Game Details

# %%
temp = df_app[df_app['game_details'].isnull() == True]

# %%
temp['url']
# Out:
# 146      https://store.steampowered.com/app/353370/Stea...
# 478      https://store.steampowered.com/app/431730/Asep...
# 663      https://store.steampowered.com/app/978680/Subs...
# 727        https://store.steampowered.com/app/479130/ESEA/
# 859      https://store.steampowered.com/app/785170/VEGA...
#                                ...
# 40234    https://store.steampowered.com/app/404110/Work...
# 40248    https://store.steampowered.com/app/358040/HTC_...
# 40367    https://store.steampowered.com/app/442310/Fore...
# 40693    https://store.steampowered.com/app/679580/Cybe...
# 40785    https://store.steampowered.com/app/914460/Init...
# Name: url, Length: 475, dtype: object

# %%
df_app.loc[2712]['game_details']
# Out:
# 'Single-player,Shared/Split Screen'

# %%
url =' https://store.steampowered.com/app/242550/Rayman_Legends/'

# %%
def get_det(url):
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")
    try: 
        return ','.join([tag.text.strip() for tag in soup.find_all('div', class_='label')])
       # return soup.find_all('div', class_='label')
    except:
        return float('nan')

# %%
get_det(url)
# Out:
# 'Single-player,Shared/Split Screen Co-op,Remote Play on Phone,Remote Play on Tablet,Remote Play Together'

# %%
for index in temp.index:
    df_app.loc[index, 'game_details'] = get_tags(df_app.loc[index, 'url'])
    print(index)
df_app['game_details'] = df_app['game_details'].replace('', float('nan'))
# Out:
# 146
# 478
# 663
# 727
# 859
# 949
# 1007
# 1052
# 1114
# 1153
# 1305
# 1409
# 1427
# 1705
# 1972
# 1979
# 2091
# 2127
# 2140
# 2202
# 2522
# 2584
# 2638
# 2662
# 2706
# 2729
# 2769
# 2799
# 2834
# 2918
# 3220
# 3318
# 3515
# 3559
# 3562
# 3622
# 3790
# 3882
# 3935
# 3966
# 4115
# 4397
# 4831
# 4847
# 4963
# 5066
# 5074
# 5091
# 5115
# 5313
# 5357
# 5399
# 5445
# 5471
# 5472
# 5473
# 5626
# 5645
# 5653
# 5700
# 5713
# 5720
# 5771
# 5972
# 6381
# 6425
# 6437
# 6450
# 6547
# 6645
# 6759
# 6761
# 6897
# 6965
# 7620
# 7869
# 8323
# 8394
# 8452
# 8509
# 8701
# 8806
# 8844
# 9037
# 9114
# 9128
# 9157
# 9158
# 9163
# 9170
# 9289
# 9429
# 9431
# 9615
# 9616
# 9948
# 9956
# 10271
# 10615
# 10656
# 10757
# 10848
# 10850
# 11618
# 11650
# 11656
# 11686
# 11757
# 11930
# 12146
# 12327
# 12430
# 12432
# 12508
# 12578
# 12879
# 12923
# 12949
# 13091
# 13259
# 13460
# 13842
# 13908
# 13926
# 14034
# 14147
# 14242
# 14253
# 14254
# 14374
# 14375
# 14848
# 15183
# 15276
# 15392
# 15416
# 15538
# 15598
# 15619
# 15687
# 15746
# 15796
# 15806
# 16041
# 16045
# 16072
# 16136
# 16206
# 16278
# 16321
# 16414
# 16417
# 16598
# 16606
# 16618
# 16622
# 16643
# 16645
# 16695
# 16696
# 16828
# 16880
# 16954
# 16956
# 17095
# 17137
# 17167
# 17218
# 17226
# 17240
# 17244
# 17308
# 17309
# 17311
# 17318
# 17326
# 17483
# 17485
# 17524
# 17577
# 17675
# 17726
# 17747
# 17775
# 17777
# 17791
# 17841
# 17861
# 17896
# 17914
# 17916
# 17917
# 17918
# 17968
# 17994
# 17995
# 18003
# 18017
# 18023
# 18031
# 18032
# 18043
# 18128
# 18177
# 18179
# 18188
# 18202
# 18229
# 18246
# 18280
# 18289
# 18346
# 18350
# 18352
# 18353
# 18368
# 18402
# 18424
# 18471
# 18507
# 18508
# 18649
# 18936
# 19036
# 19041
# 19070
# 19080
# 19171
# 19184
# 19285
# 19459
# 19475
# 19590
# 19812
# 19864
# 19991
# 20001
# 20120
# 20238
# 20279
# 20345
# 20369
# 20447
# 20495
# 20649
# 20651
# 20757
# 20825
# 20863
# 20872
# 20876
# 20966
# 21058
# 21310
# 21423
# 21455
# 21515
# 21836
# 22235
# 22381
# 22427
# 22428
# 22429
# 22475
# 22488
# 22896
# 22991
# 23099
# 23205
# 23240
# 23288
# 23360
# 23556
# 23591
# 23700
# 23776
# 23819
# 23998
# 24010
# 24071
# 24133
# 24144
# 24263
# 24386
# 24486
# 24525
# 24598
# 24599
# 24659
# 24665
# 24685
# 24700
# 24748
# 24778
# 24782
# 24888
# 25064
# 25105
# 25225
# 25277
# 25326
# 25334
# 25364
# 25383
# 25423
# 25425
# 25503
# 25596
# 25657
# 25829
# 25904
# 25998
# 26019
# 26033
# 26145
# 26233
# 26248
# 26668
# 26680
# 26684
# 26685
# 26875
# 26894
# 26978
# 26982
# 27069
# 27095
# 27208
# 27250
# 27293
# 27320
# 27346
# 27372
# 27481
# 27490
# 27492
# 27496
# 27497
# 27545
# 27628
# 27659
# 27710
# 27778
# 27950
# 27961
# 28005
# 28041
# 28076
# 28078
# 28079
# 28096
# 28138
# 28255
# 28322
# 28354
# 28380
# 28445
# 28498
# 28511
# 28610
# 28704
# 28732
# 28741
# 28761
# 28812
# 28867
# 28932
# 28971
# 29110
# 29138
# 29189
# 29190
# 29309
# 29317
# 29320
# 29323
# 29326
# 29366
# 29375
# 29387
# 29579
# 29800
# 29801
# 29802
# 29804
# 29805
# 29884
# 29915
# 30056
# 30078
# 30116
# 30135
# 30136
# 30364
# 30405
# 30497
# 30601
# 30608
# 30623
# 30645
# 30669
# 30758
# 30787
# 30821
# 30853
# 31081
# 31177
# 33614
# 33730
# 33741
# 34684
# 34726
# 35060
# 35472
# 35821
# 35992
# 36154
# 36284
# 36584
# 36585
# 36586
# 36587
# 36589
# 36590
# 36685
# 36701
# 36821
# 36857
# 36874
# 36913
# 36914
# 37251
# 37314
# 37383
# 37456
# 37489
# 37835
# 37837
# 37931
# 38036
# 38039
# 38040
# 38088
# 38089
# 38090
# 38091
# 38104
# 38106
# 38146
# 38372
# 38509
# 38512
# 38610
# 38751
# 38830
# 38919
# 39037
# 39038
# 39042
# 39100
# 39153
# 39158
# 39159
# 39160
# 39457
# 39458
# 39705
# 39721
# 39934
# 40133
# 40234
# 40248
# 40367
# 40693
# 40785
# /var/folders/dv/7t_6tkbx07s6mfq_r5jxkp240000gp/T/ipykernel_25097/2235482491.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_app['game_details'] = df_app['game_details'].replace('', float('nan'))

# %%
df_app[df_app['game_details'].isnull() == True]
# Out:
#                                                      url types  \
# 4847   https://store.steampowered.com/bundle/6191/The...   app
# 6381   https://store.steampowered.com/bundle/7125/Fac...   app
# 7869   https://store.steampowered.com/bundle/10241/Da...   app
# 9615   https://store.steampowered.com/bundle/8069/Hap...   app
# 9616   https://store.steampowered.com/bundle/7988/Scr...   app
# 9956   https://store.steampowered.com/bundle/5057/Del...   app
# 12146  https://store.steampowered.com/bundle/10912/Th...   app
# 12508  https://store.steampowered.com/app/830640/DayZ...   app
# 12578  https://store.steampowered.com/app/783970/Fly_...   app
# 12879  https://store.steampowered.com/bundle/2663/PSY...   app
# 13908  https://store.steampowered.com/app/382990/Brai...   app
# 15619  https://store.steampowered.com/app/451330/IS_D...   app
# 20757  https://store.steampowered.com/app/643890/flCh...   app
# 23099  https://store.steampowered.com/bundle/5704/Hap...   app
# 27069  https://store.steampowered.com/app/451450/Holl...   app
# 28380  https://store.steampowered.com/bundle/10417/Ha...   app
# 33730  https://store.steampowered.com/app/530260/Stea...   app
# 34726  https://store.steampowered.com/app/396540/Clif...   app
# 37251  https://store.steampowered.com/app/623590/Prof...   app
# 39934  https://store.steampowered.com/app/1059530/Val...   app
#
#                                      name  \
# 4847                                  NaN
# 6381                                  NaN
# 7869                                  NaN
# 9615                                  NaN
# 9616                                  NaN
# 9956                                  NaN
# 12146                                 NaN
# 12508                          DayZ Tools
# 12578                       Fly the plane
# 12879                                 NaN
# 13908              BrainBread 2 Mod Tools
# 15619                   IS Defense Editor
# 20757                             flChess
# 23099                                 NaN
# 27069             Hollywood Hills Mansion
# 28380                                 NaN
# 33730  Steam Controller Wireless Receiver
# 34726   Cliffs of War: Fortress Defenders
# 37251   Professor Teaches QuickBooks 2017
# 39934                 Valve Index Headset
#
#                                             desc_snippet recent_reviews  \
# 4847                                                 NaN            NaN
# 6381                                                 NaN            NaN
# 7869                                                 NaN            NaN
# 9615                                                 NaN            NaN
# 9616                                                 NaN            NaN
# 9956                                                 NaN            NaN
# 12146                                                NaN            NaN
# 12508  A complete tools suite for the game engine pow...            NaN
# 12578  Fly the plane is a casual and funny game made ...            NaN
# 12879                                                NaN            NaN
# 13908                                                NaN            NaN
# 15619                                                NaN            NaN
# 20757  Chess game with advanced artificial intellect ...            NaN
# 23099                                                NaN            NaN
# 27069  The Hollywood Hills Mansion is the perfect spa...            NaN
# 28380                                                NaN            NaN
# 33730  Grab a wireless receiver (dongle) as a replace...            NaN
# 34726                                 The game is closed            NaN
# 37251  Professor Teaches QuickBooks 2017 is computer ...            NaN
# 39934                                                NaN            NaN
#
#                                              all_reviews  release_date  \
# 4847                                                 NaN           NaN
# 6381                                                 NaN           NaN
# 7869                                                 NaN           NaN
# 9615                                                 NaN           NaN
# 9616                                                 NaN           NaN
# 9956                                                 NaN           NaN
# 12146                                                NaN           NaN
# 12508  Positive,(27),- 88% of the 27 user reviews for...   Nov 7, 2018
# 12578  1 user reviews,- Need more user reviews to gen...   Feb 9, 2018
# 12879                                                NaN           NaN
# 13908                                                NaN  Feb 17, 2016
# 15619  5 user reviews,- Need more user reviews to gen...  Apr 29, 2016
# 20757  Mostly Positive,(68),- 73% of the 68 user revi...  May 29, 2017
# 23099                                                NaN           NaN
# 27069  6 user reviews,- Need more user reviews to gen...   Feb 2, 2017
# 28380                                                NaN           NaN
# 33730                                                NaN  Sep 29, 2016
# 34726                                                NaN   Nov 3, 2015
# 37251                                                NaN   Apr 3, 2017
# 39934                                                NaN           NaN
#
#                        developer            publisher  \
# 4847                         NaN                 None
# 6381                         NaN                 None
# 7869                         NaN                 None
# 9615                         NaN                 None
# 9616                         NaN                 None
# 9956                         NaN                 None
# 12146                        NaN                 None
# 12508        Bohemia Interactive  Bohemia Interactive
# 12578               Dexion Games         Dexion Games
# 12879                        NaN                 None
# 13908                        NaN                 None
# 15619                        NaN                 None
# 20757  Flying. Stone. Production           Atriagames
# 23099                        NaN                 None
# 27069      LOOT Interactive, LLC                 None
# 28380                        NaN                 None
# 33730                        NaN                 None
# 34726                        NaN                 None
# 37251        Individual Software  Individual Software
# 39934                        NaN                 None
#
#                                     popular_tags  ... languages achievements  \
# 4847                                         NaN  ...       NaN          NaN
# 6381                                         NaN  ...       NaN          NaN
# 7869                                         NaN  ...       NaN          NaN
# 9615                                         NaN  ...       NaN          NaN
# 9616                                         NaN  ...       NaN          NaN
# 9956                                         NaN  ...       NaN          NaN
# 12146                                        NaN  ...       NaN          NaN
# 12508                                        NaN  ...   English          NaN
# 12578                               Casual,Indie  ...   English          NaN
# 12879                                        NaN  ...       NaN          NaN
# 13908                                        NaN  ...   English          NaN
# 15619                                        NaN  ...   English          NaN
# 20757  Indie,Sports,Board Game,Chess,Multiplayer  ...   English          9.0
# 23099                                        NaN  ...       NaN          NaN
# 27069                                        NaN  ...   English          NaN
# 28380                                        NaN  ...       NaN          NaN
# 33730                                   Hardware  ...       NaN          NaN
# 34726                                        NaN  ...   English          NaN
# 37251                                        NaN  ...   English          NaN
# 39934                                        NaN  ...       NaN          NaN
#
#               genre                                   game_description  \
# 4847            NaN   About this bundle  Get all extra characters i...
# 6381            NaN   About this bundle  This bundle contains  thre...
# 7869            NaN                                                NaN
# 9615            NaN   About this bundle  Happy Bat VR Bundle contai...
# 9616            NaN   About this bundle  Get the base game and all ...
# 9956            NaN   About this bundle  Benefit from -25% on this ...
# 12146           NaN          About this bundle  All Joe Papp content.
# 12508           NaN   About This Game DayZ Tools is a complete tool...
# 12578  Casual,Indie   About This Game In "Fly the plane" you will f...
# 12879           NaN   About this bundle  The ultimate PSYCHO-PASS g...
# 13908           NaN                                                NaN
# 15619           NaN                                                NaN
# 20757  Indie,Sports   About This Game Chess game with advanced arti...
# 23099           NaN   About this bundle  Game + DLC = Happy New Yea...
# 27069           NaN   About This Software The Hollywood Hills Mansi...
# 28380           NaN   About this bundle  Purchase this bundle to sa...
# 33730         Valve   About This Hardware Grab a wireless receiver ...
# 34726           NaN                                                NaN
# 37251    Accounting   About This Software Professor Teaches QuickBo...
# 39934         Valve        Reserve now to be notified of availabili...
#
#       mature_content                               minimum_requirements  \
# 4847             NaN                                                NaN
# 6381             NaN                                                NaN
# 7869             NaN                                                NaN
# 9615             NaN                                                NaN
# 9616             NaN                                                NaN
# 9956             NaN                                                NaN
# 12146            NaN                                                NaN
# 12508            NaN                                                NaN
# 12578            NaN                                                NaN
# 12879            NaN                                                NaN
# 13908            NaN                                                NaN
# 15619            NaN                                                NaN
# 20757            NaN                                                NaN
# 23099            NaN                                                NaN
# 27069            NaN  Minimum:,Requires a 64-bit processor and opera...
# 28380            NaN                                                NaN
# 33730            NaN                                                NaN
# 34726            NaN                                                NaN
# 37251            NaN                                                NaN
# 39934            NaN  Minimum:,OS:,Windows 10,Processor:,Dual Core w...
#
#                                 recommended_requirements original_price  \
# 4847                                                 NaN            NaN
# 6381                                                 NaN            NaN
# 7869                                                 NaN            NaN
# 9615                                                 NaN            NaN
# 9616                                                 NaN            NaN
# 9956                                                 NaN            NaN
# 12146                                                NaN            NaN
# 12508                                                NaN            NaN
# 12578                                                NaN          $0.99
# 12879                                                NaN            NaN
# 13908                                                NaN            NaN
# 15619                                                NaN            NaN
# 20757                                                NaN          $1.99
# 23099                                                NaN            NaN
# 27069  Recommended:,Requires a 64-bit processor and o...          $4.99
# 28380                                                NaN            NaN
# 33730                                                NaN         $12.99
# 34726                                                NaN            NaN
# 37251                                                NaN         $14.99
# 39934  Recommended:,Processor:,Quad Core +,Graphics:,...        $499.00
#
#       discount_price achievement_cat
# 4847          $18.84               0
# 6381           $2.67               0
# 7869          $53.96               0
# 9615          $11.03               0
# 9616          $12.55               0
# 9956           $1.48               0
# 12146          $9.96               0
# 12508            NaN               0
# 12578            NaN               0
# 12879         $32.28               0
# 13908            NaN               0
# 15619            NaN               0
# 20757        $103.77               1
# 23099          $1.98               0
# 27069            NaN               0
# 28380         $16.55               0
# 33730            NaN               0
# 34726            NaN               0
# 37251         $21.00               0
# 39934            NaN               0
#
# [20 rows x 21 columns]
